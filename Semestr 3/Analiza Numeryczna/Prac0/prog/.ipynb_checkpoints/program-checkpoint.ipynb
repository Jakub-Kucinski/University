# %% [markdown]
# Ilustracja działania kodu programu program.jl:

# %%
using Plots
x = 1:10; y = rand(10);
pl = plot(x,y);
pl

# %% [markdown]
# Program.jl zawiera na końcu polecenie:
# savefig(pl, "plot.png");
# Powoduje ono zapisanie wykresu pl do pliku plot.png do katalogu roboczego programu.
