# %%
import numpy as np
import matplotlib.pyplot as plt
from pymoo.algorithms.nsga2 import NSGA2
from pymoo.model.problem import Problem
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.factory import get_problem
from pymoo.factory import get_mutation
from pymoo.factory import get_sampling
from pymoo.factory import get_selection
from pymoo.factory import get_sampling
from pymoo.factory import get_crossover

# %%
def tsp_objective_function(Distance_matrix, p):
    s = 0.0
    n = len(p)
    for i in range(n):
        s += Distance_matrix[p[i-1], p[i]]
    return s

# %%
def euclidA100():
    coords_string = """1 2066 2333
    2 935 1304
    3 1270 200
    4 1389 700
    5 984 2810
    6 2253 478
    7 949 3025
    8 87 2483
    9 3094 1883
    10 2706 3130
    11 857 177
    12 1270 1501
    13 2782 2557
    14 282 73
    15 2097 1014
    16 1913 299
    17 2454 2605
    18 2781 2118
    19 2936 2843
    20 3105 1962
    21 2899 258
    22 2574 2325
    23 856 1857
    24 807 1178
    25 207 1072
    26 643 2134
    27 911 1256
    28 75 1766
    29 3041 1492
    30 1686 2314
    31 426 1708
    32 757 2185
    33 3074 1994
    34 1067 1787
    35 2168 1393
    36 1676 1916
    37 1675 1634
    38 2486 1885
    39 2428 14
    40 1425 1015
    41 2679 1953
    42 1549 2946
    43 588 204
    44 2704 269
    45 2694 786
    46 1051 1149
    47 674 1712
    48 286 982
    49 1745 939
    50 3001 2133
    51 2591 792
    52 2916 2354
    53 1555 1853
    54 584 1128
    55 668 3034
    56 2225 2772
    57 1960 900
    58 1262 2440
    59 1034 2208
    60 1898 2091
    61 249 127
    62 1948 35
    63 1965 883
    64 2163 2484
    65 78 632
    66 1300 1300
    67 2508 1553
    68 1953 3070
    69 3155 649
    70 1683 1310
    71 2333 495
    72 1533 602
    73 536 924
    74 2364 639
    75 2909 2566
    76 1982 2424
    77 860 2369
    78 832 1290
    79 1446 1362
    80 400 1648
    81 1860 3098
    82 2607 2521
    83 701 1729
    84 1239 1357
    85 363 338
    86 76 394
    87 2461 2495
    88 109 987
    89 2429 2741
    90 2365 674
    91 2599 800
    92 2083 1592
    93 1935 1365
    94 1856 3150
    95 852 224
    96 1830 1798
    97 285 1345
    98 1233 1939
    99 1197 2200
    100 493 2712"""
    n = 100
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        next(it)
        coords[i, 0] = float(next(it))
        coords[i, 1] = float(next(it))
    distance_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            distance_matrix[i, j] = np.sqrt(((coords[i, :] - coords[j, :])**2).sum())
    return distance_matrix, coords

# %%
def euclidB100():
    coords_string = """1 2374 197
    2 2166 878
    3 644 5
    4 268 3149
    5 706 2256
    6 2180 2557
    7 1397 771
    8 1356 42
    9 430 1110
    10 2827 1530
    11 762 2418
    12 1150 1031
    13 2227 1932
    14 690 2003
    15 514 1034
    16 310 397
    17 1506 2494
    18 506 1023
    19 2832 366
    20 12 2743
    21 408 1154
    22 2189 3038
    23 220 703
    24 849 2570
    25 2424 392
    26 3160 3155
    27 2606 1401
    28 324 1976
    29 1854 2834
    30 372 2784
    31 335 3064
    32 3136 1126
    33 1848 1025
    34 367 1521
    35 550 652
    36 2355 1023
    37 1849 2434
    38 1532 770
    39 2974 2912
    40 706 250
    41 78 1018
    42 1631 893
    43 699 409
    44 423 380
    45 646 2643
    46 656 1310
    47 2979 2522
    48 387 2547
    49 2468 2918
    50 1506 2613
    51 891 1100
    52 1863 2173
    53 314 2142
    54 1524 1713
    55 702 3078
    56 1553 1474
    57 2188 891
    58 2127 2187
    59 85 614
    60 738 2463
    61 1720 611
    62 15 1100
    63 2924 1255
    64 2322 2838
    65 2119 2553
    66 2409 1261
    67 2209 790
    68 1860 1767
    69 1992 739
    70 1928 1674
    71 323 2972
    72 2804 1345
    73 923 44
    74 1295 1878
    75 2761 2295
    76 225 2792
    77 798 2116
    78 203 2793
    79 2053 1073
    80 313 1710
    81 149 784
    82 2947 2190
    83 2755 1743
    84 1832 843
    85 3130 2082
    86 892 1370
    87 1015 1606
    88 2238 2090
    89 2976 1062
    90 896 131
    91 2365 1249
    92 2525 409
    93 2403 1625
    94 1476 18
    95 1197 116
    96 3098 1149
    97 772 3008
    98 781 2115
    99 1956 1198
    100 2270 1996"""
    n = 100
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        next(it)
        coords[i, 0] = float(next(it))
        coords[i, 1] = float(next(it))
    distance_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            distance_matrix[i, j] = np.sqrt(((coords[i, :] - coords[j, :])**2).sum())
    return distance_matrix, coords

# %%
def euclidC100():
    coords_string = """1 2681 1225
    2 234 452
    3 19 2973
    4 2310 2434
    5 427 1702
    6 2106 1473
    7 1846 1680
    8 2624 763
    9 930 338
    10 2947 3093
    11 668 1496
    12 1029 562
    13 1672 1307
    14 1097 769
    15 2093 1054
    16 1871 494
    17 558 2382
    18 1394 3091
    19 2729 1052
    20 82 360
    21 1080 2050
    22 1805 589
    23 2748 2712
    24 891 799
    25 1478 2876
    26 2514 1012
    27 1138 1546
    28 573 2187
    29 667 1014
    30 2220 90
    31 244 1257
    32 2352 66
    33 622 56
    34 2830 1256
    35 2095 3074
    36 3035 130
    37 2022 71
    38 578 2818
    39 358 2646
    40 3151 2648
    41 639 83
    42 1712 2002
    43 810 613
    44 1305 491
    45 1760 1338
    46 261 1472
    47 2120 170
    48 488 950
    49 28 1734
    50 11 3092
    51 2354 1407
    52 811 1992
    53 2236 2431
    54 2463 2298
    55 735 3123
    56 881 175
    57 2416 882
    58 2992 1934
    59 2300 2182
    60 2740 2835
    61 28 1096
    62 1245 2165
    63 720 1627
    64 2481 29
    65 997 1310
    66 355 1222
    67 1910 27
    68 1767 464
    69 829 830
    70 2173 2038
    71 1475 2286
    72 913 2088
    73 1310 2328
    74 226 3117
    75 2613 2023
    76 1631 3161
    77 736 1863
    78 2737 1132
    79 2659 783
    80 225 1772
    81 1601 1633
    82 125 1860
    83 1647 1758
    84 2425 328
    85 2734 664
    86 1708 2346
    87 2732 717
    88 1204 29
    89 359 2545
    90 2591 2750
    91 2130 1698
    92 2967 2388
    93 2871 1884
    94 1096 49
    95 1543 8
    96 1202 501
    97 1258 1509
    98 330 2292
    99 2716 196
    100 884 1280"""
    n = 100
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        next(it)
        coords[i, 0] = float(next(it))
        coords[i, 1] = float(next(it))
    distance_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            distance_matrix[i, j] = np.sqrt(((coords[i, :] - coords[j, :])**2).sum())
    return distance_matrix, coords

# %%
def euclidD100():
    coords_string = """1 2989 2252
    2 1465 25
    3 2557 2779
    4 1189 1719
    5 148 1148
    6 2033 389
    7 2295 2590
    8 730 1485
    9 1429 2728
    10 3068 1493
    11 573 574
    12 909 92
    13 1117 681
    14 1504 2699
    15 509 1074
    16 269 592
    17 2772 2271
    18 2282 1997
    19 2625 1738
    20 151 1141
    21 1752 2946
    22 1421 1303
    23 2112 1559
    24 933 2192
    25 532 2197
    26 1868 2033
    27 2833 1691
    28 822 2397
    29 2643 2356
    30 905 560
    31 153 2614
    32 1568 2170
    33 2559 2249
    34 2130 991
    35 477 2334
    36 551 2400
    37 2196 871
    38 2788 1703
    39 904 2381
    40 2432 1883
    41 1201 2311
    42 1793 3112
    43 921 818
    44 2187 602
    45 2875 33
    46 3029 1634
    47 1261 980
    48 589 2515
    49 750 550
    50 1678 409
    51 655 1714
    52 2922 1811
    53 995 2720
    54 239 2884
    55 769 4
    56 209 2040
    57 2644 872
    58 694 1682
    59 1352 587
    60 1580 44
    61 1498 1580
    62 2476 68
    63 1679 2000
    64 2640 384
    65 3039 67
    66 1463 1183
    67 1611 2428
    68 1673 2324
    69 2829 920
    70 2418 2402
    71 2628 1599
    72 2185 2831
    73 1697 1448
    74 2321 1192
    75 2464 1752
    76 3037 366
    77 674 1610
    78 2108 2635
    79 103 494
    80 137 1834
    81 3053 2482
    82 465 1530
    83 539 1772
    84 3018 2976
    85 2338 2408
    86 2523 159
    87 1285 2990
    88 169 1132
    89 906 865
    90 1122 2206
    91 1896 2146
    92 246 1204
    93 177 2144
    94 717 81
    95 1889 3063
    96 2469 3016
    97 1745 9
    98 3041 2468
    99 313 2357
    100 2661 564"""
    n = 100
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        next(it)
        coords[i, 0] = float(next(it))
        coords[i, 1] = float(next(it))
    distance_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            distance_matrix[i, j] = np.sqrt(((coords[i, :] - coords[j, :])**2).sum())
    return distance_matrix, coords

# %%
def euclidE100():
    coords_string = """1 134 117
    2 2696 2762
    3 1932 2584
    4 68 1005
    5 3033 594
    6 1960 2468
    7 2743 336
    8 1998 2206
    9 1928 1955
    10 25 3056
    11 478 2815
    12 788 2785
    13 562 56
    14 1912 1465
    15 2088 1094
    16 1829 690
    17 1824 2160
    18 7 902
    19 2522 2424
    20 221 1922
    21 2424 679
    22 1037 2017
    23 1476 405
    24 975 421
    25 2749 1517
    26 1222 3053
    27 1365 1835
    28 1071 2607
    29 1455 536
    30 2754 1029
    31 62 807
    32 783 1110
    33 1333 1280
    34 1431 726
    35 2022 1593
    36 1231 1507
    37 2369 1671
    38 1834 588
    39 1450 2115
    40 1714 1118
    41 1763 1376
    42 1874 1058
    43 1032 1022
    44 3069 713
    45 826 1890
    46 2634 1795
    47 402 1791
    48 690 917
    49 1473 2529
    50 183 888
    51 2118 2022
    52 1870 1630
    53 2917 3009
    54 1179 306
    55 803 48
    56 2701 741
    57 2872 863
    58 1558 1429
    59 404 2155
    60 419 415
    61 2969 2065
    62 543 1133
    63 2637 2372
    64 2800 738
    65 1917 1988
    66 2572 1143
    67 1312 1665
    68 1580 1021
    69 1666 1011
    70 2663 2766
    71 618 913
    72 293 410
    73 2083 569
    74 1252 2431
    75 2316 1481
    76 1280 734
    77 611 1358
    78 1479 974
    79 709 204
    80 50 1895
    81 1342 167
    82 806 1200
    83 2593 1787
    84 447 2461
    85 1942 989
    86 176 1136
    87 3002 2101
    88 2298 2235
    89 1453 2348
    90 2817 1663
    91 1662 2595
    92 688 21
    93 645 2404
    94 337 112
    95 2234 2955
    96 573 2368
    97 2231 1673
    98 2589 2644
    99 1073 1355
    100 1275 3011"""
    n = 100
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        next(it)
        coords[i, 0] = float(next(it))
        coords[i, 1] = float(next(it))
    distance_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            distance_matrix[i, j] = np.sqrt(((coords[i, :] - coords[j, :])**2).sum())
    return distance_matrix, coords

# %%
def euclidF100():
    coords_string = """1 442 1145
    2 764 2335
    3 1306 2389
    4 2111 290
    5 2754 41
    6 1886 1384
    7 29 1245
    8 104 2928
    9 2427 1183
    10 146 1456
    11 384 1893
    12 668 2316
    13 8 2593
    14 2319 232
    15 505 1114
    16 227 787
    17 876 2048
    18 896 2970
    19 2418 3110
    20 291 2703
    21 3096 1575
    22 653 2731
    23 841 2414
    24 1017 1813
    25 1803 838
    26 576 911
    27 3060 1980
    28 1320 2817
    29 268 1878
    30 1439 1499
    31 3134 2163
    32 3162 51
    33 107 310
    34 731 461
    35 404 852
    36 1911 614
    37 2542 2471
    38 880 2636
    39 1996 1850
    40 995 353
    41 2325 440
    42 1955 2168
    43 1143 1227
    44 788 825
    45 1941 585
    46 2238 1957
    47 2706 2601
    48 791 2482
    49 2196 1345
    50 1850 1367
    51 418 2329
    52 817 1449
    53 1675 135
    54 2118 891
    55 837 93
    56 2029 2606
    57 3100 854
    58 2423 1176
    59 2619 561
    60 2422 787
    61 1277 2549
    62 1773 2199
    63 433 2744
    64 2959 1093
    65 795 745
    66 517 1104
    67 1013 902
    68 1487 2881
    69 503 1101
    70 2907 3130
    71 1770 227
    72 1565 1153
    73 2470 2852
    74 184 507
    75 2167 1210
    76 2686 1102
    77 549 1105
    78 850 2476
    79 1316 3078
    80 3125 1957
    81 2794 1016
    82 1146 870
    83 1485 1802
    84 1040 1946
    85 1546 2734
    86 992 2112
    87 1556 1212
    88 1264 174
    89 1999 668
    90 1349 1119
    91 1428 3044
    92 1130 2000
    93 1113 2663
    94 3120 143
    95 2580 2847
    96 1840 1719
    97 2717 173
    98 2137 2821
    99 1833 353
    100 3051 2295"""
    n = 100
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        next(it)
        coords[i, 0] = float(next(it))
        coords[i, 1] = float(next(it))
    distance_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            distance_matrix[i, j] = np.sqrt(((coords[i, :] - coords[j, :])**2).sum())
    return distance_matrix, coords

# %%
def euclidAB100():
    coords_string= """25124	167169
    25132	164356
    25140	163822
    25150	163402
    25161	163193
    25168	163074
    25169	160380
    25177	159846
    25187	159426
    25205	159098
    25240	158966
    25248	158768
    25258	158638
    25295	157942
    25299	157410
    25307	156876
    25317	156456
    25335	156128
    25375	156005
    25378	155798
    25393	155737
    25394	155696
    25396	155470
    25409	155264
    25417	154880
    25419	154844
    25435	154552
    25437	154516
    25458	154162
    25464	153506
    25474	153086
    25492	152758
    25532	152635
    25535	152428
    25542	152392
    25550	151939
    25568	151611
    25574	151510
    25588	151192
    25592	151182
    25598	150772
    25616	150444
    25643	150399
    25654	150360
    25659	150114
    25668	150035
    25670	149389
    25680	148969
    25698	148641
    25709	148602
    25727	148274
    25756	148250
    25759	147983
    25770	147813
    25780	147393
    25798	147065
    25823	146708
    25833	146288
    25851	145960
    25878	145915
    25897	145799
    25905	144905
    25915	144485
    25933	144157
    25973	144034
    25991	143766
    26010	143580
    26020	143160
    26038	142832
    26078	142709
    26080	142672
    26096	142441
    26138	142281
    26164	142131
    26167	141675
    26185	141347
    26225	141014
    26243	140686
    26283	140563
    26285	139976
    26295	139556
    26313	139228
    26353	139105
    26371	138837
    26434	138605
    26439	138527
    26442	138071
    26460	137743
    26500	137620
    26518	137352
    26550	137292
    26568	136964
    26587	136715
    26597	136619
    26605	136085
    26623	135757
    26663	135634
    26681	135366
    26734	135230
    26744	135134
    26749	135056
    26752	134600
    26770	134272
    26810	134149
    26828	133881
    26868	133758
    26896	133571
    26932	133569
    26936	133448
    26949	133358
    26954	133180
    26990	133178
    27001	133079
    27007	132967
    27058	132868
    27059	132705
    27069	132504
    27079	132084
    27119	131961
    27137	131693
    27171	131379
    27189	131051
    27247	130990
    27265	130662
    27267	130602
    27285	130274
    27318	129894
    27336	129566
    27399	129378
    27402	129374
    27420	129046
    27462	128865
    27495	128601
    27498	128597
    27516	128269
    27528	128221
    27546	127893
    27549	127889
    27567	127561
    27639	127402
    27645	127378
    27657	127239
    27704	127108
    27719	127091
    27722	127087
    27729	126858
    27740	126759
    27764	126520
    27767	126516
    27785	126188
    27825	126081
    27855	125705
    27876	125373
    27935	125103
    27966	125051
    28007	124944
    28013	124920
    28028	124903
    28037	124793
    28043	124708
    28049	124571
    28073	124332
    28094	124000
    28153	123730
    28176	123547
    28186	123501
    28223	123247
    28244	122915
    28316	122756
    28346	122605
    28376	122502
    28383	122460
    28394	122174
    28404	122128
    28417	122113
    28441	121874
    28462	121542
    28485	121359
    28547	121261
    28554	121043
    28588	120887
    28630	120654
    28658	120557
    28693	120406
    28703	119986
    28765	119888
    28772	119670
    28795	119487
    28848	119281
    28871	119098
    28898	119015
    28933	119000
    28940	118881
    28945	118868
    28968	118685
    28974	118626
    29003	118534
    29006	118332
    29013	118114
    29075	118016
    29089	117725
    29116	117642
    29151	117627
    29158	117508
    29174	117444
    29186	117312
    29192	117253
    29243	117227
    29248	117214
    29250	117209
    29261	117036
    29262	116923
    29289	116840
    29316	116460
    29365	116451
    29392	116071
    29419	115988
    29461	115854
    29480	115799
    29489	115658
    29495	115599
    29549	115582
    29550	115578
    29553	115555
    29557	115360
    29565	115269
    29592	115186
    29629	115166
    29633	114971
    29655	114824
    29668	114797
    29702	114754
    29707	114534
    29731	114435
    29746	114420
    29758	114352
    29773	114337
    29783	114145
    29810	114062
    29828	114022
    29834	113963
    29849	113948
    29852	113928
    29860	113706
    29886	113673
    29904	113633
    29919	113618
    29931	113550
    29936	113317
    29963	113234
    29973	113155
    30005	113100
    30024	113045
    30033	112904
    30039	112845
    30049	112766
    30076	112683
    30108	112628
    30109	112515
    30122	112509
    30136	112432
    30146	112353
    30152	112294
    30191	112292
    30197	112243
    30212	112043
    30222	111964
    30249	111881
    30251	111780
    30290	111666
    30312	111519
    30325	111492
    30327	111391
    30354	111308
    30387	111253
    30388	111130
    30415	111047
    30424	110978
    30430	110919
    30457	110913
    30463	110864
    30466	110693
    30491	110658
    30500	110589
    30517	110401
    30561	110328
    30588	110245
    30593	110012
    30620	109929
    30646	109872
    30662	109795
    30690	109599
    30696	109540
    30731	109437
    30749	109400
    30754	109289
    30765	109269
    30766	109210
    30769	109039
    30826	108994
    30835	108993
    30851	108966
    30857	108767
    30866	108716
    30911	108617
    30929	108522
    30938	108521
    30954	108444
    30969	108244
    31000	108221
    31009	108219
    31019	108033
    31037	107946
    31045	107918
    31053	107865
    31057	107635
    31114	107590
    31122	107511
    31123	107388
    31145	107363
    31154	107312
    31160	107113
    31217	107068
    31220	107065
    31242	107040
    31251	106924
    31257	106790
    31303	106567
    31312	106565
    31356	106548
    31360	106318
    31388	106132
    31406	106095
    31411	105984
    31422	105964
    31426	105734
    31448	105709
    31483	105689
    31505	105664
    31508	105661
    31517	105545
    31523	105411
    31545	105386
    31577	105357
    31586	105217
    31600	105161
    31626	104939
    31648	104914
    31676	104728
    31702	104613
    31710	104560
    31714	104330
    31771	104285
    31805	104141
    31811	104007
    31874	103813
    31910	103765
    31914	103535
    31954	103510
    31965	103490
    31969	103260
    31991	103235
    32040	103172
    32060	103071
    32082	103046
    32120	102883
    32129	102843
    32186	102798
    32195	102678
    32197	102628
    32207	102537
    32219	102254
    32245	102139
    32253	102086
    32257	101856
    32348	101667
    32387	101635
    32421	101557
    32472	101481
    32478	101446
    32483	101274
    32526	101179
    32542	101113
    32545	101096
    32571	100981
    32579	100928
    32583	100698
    32660	100652
    32668	100599
    32672	100369
    32763	100180
    32809	100116
    32852	100021
    32868	99955
    32898	99787
    32941	99692
    32957	99626
    32984	99499
    33048	99437
    33074	99228
    33114	99020
    33179	98946
    33210	98917
    33213	98778
    33217	98548
    33347	98390
    33353	98378
    33386	98358
    33409	98333
    33412	98316
    33419	98265
    33426	98108
    33436	98061
    33442	98049
    33443	97966
    33450	97918
    33457	97867
    33525	97866
    33529	97636
    33539	97589
    33557	97567
    33636	97383
    33646	97238
    33694	97207
    33698	96977
    33744	96947
    33778	96779
    33782	96549
    33872	96380
    33912	96328
    33946	96250
    33962	96225
    33963	96191
    34016	96130
    34020	96049
    34024	95819
    34067	95806
    34070	95789
    34100	95702
    34104	95621
    34108	95391
    34193	95292
    34197	95062
    34314	95031
    34326	94980
    34367	94894
    34389	94878
    34393	94648
    34417	94559
    34478	94549
    34482	94319
    34509	94192
    34596	94075
    34624	93953
    34649	93769
    34658	93669
    34704	93639
    34738	93471
    34742	93241
    34871	93159
    34872	93083
    34898	92988
    34944	92958
    34951	92801
    34961	92754
    34975	92611
    34982	92560
    35050	92559
    35054	92329
    35064	92282
    35146	92261
    35162	92236
    35186	92228
    35193	92200
    35220	92060
    35224	91830
    35267	91817
    35270	91800
    35272	91767
    35300	91713
    35304	91632
    35308	91402
    35393	91303
    35397	91073
    35526	90991
    35567	90905
    35589	90889
    35593	90659
    35676	90631
    35678	90560
    35682	90330
    35743	90268
    35746	90252
    35796	90086
    35820	90078
    35824	89964
    35849	89780
    35858	89680
    35904	89650
    35938	89482
    35942	89252
    36071	89170
    36072	89094
    36134	89037
    36137	89020
    36151	88812
    36161	88765
    36175	88622
    36250	88570
    36254	88340
    36264	88293
    36383	88258
    36388	88206
    36434	88176
    36446	88022
    36460	87879
    36472	87778
    36549	87550
    36605	87524
    36678	87468
    36716	87395
    36735	87366
    36748	87264
    36775	87255
    36794	87234
    36824	87037
    36832	86836
    36917	86612
    36927	86565
    37022	86490
    37026	86260
    37123	86151
    37135	86050
    37200	86002
    37212	85822
    37295	85719
    37310	85691
    37380	85620
    37384	85390
    37399	85362
    37446	85309
    37485	85259
    37492	85245
    37495	85108
    37535	84980
    37568	84856
    37658	84855
    37669	84647
    37714	84538
    37731	84408
    37793	84389
    37817	84356
    37820	84297
    37860	84248
    37867	84215
    37892	84138
    37897	84041
    37909	83968
    37949	83919
    37962	83896
    37976	83753
    38023	83671
    38025	83638
    38048	83594
    38065	83424
    38083	83378
    38123	83329
    38137	83265
    38172	83049
    38212	83000
    38225	82977
    38239	82834
    38328	82505
    38431	82495
    38469	82466
    38505	82457
    38527	82394
    38533	82064
    38622	81735
    38756	81690
    38811	81595
    38814	81528
    38851	81407
    38893	81378
    38940	81078
    39029	81065
    39076	80940
    39101	80906
    39105	80825
    39108	80758
    39146	80736
    39165	80611
    39203	80475
    39292	80146
    39428	80008
    39440	79966
    39517	79679
    39587	79597
    39620	79550
    39676	79268
    39775	79236
    39817	79229
    39818	79208
    39875	79157
    39881	78827
    39970	78498
    40104	78453
    40159	78358
    40162	78291
    40199	78170
    40241	78141
    40288	77841
    40377	77828
    40424	77703
    40449	77669
    40453	77588
    40456	77521
    40513	77374
    40551	77238
    40640	76909
    40776	76771
    40841	76609
    40865	76442
    40968	76313
    41072	76294
    41122	76261
    41123	75999
    41179	75995
    41230	75884
    41262	75766
    41324	75699
    41348	75532
    41408	75530
    41416	75489
    41437	75453
    41442	75392
    41531	75063
    41653	75034
    41661	75016
    41710	74990
    41713	74974
    41730	74952
    41732	74763
    41742	74705
    41809	74669
    41860	74627
    41878	74567
    41920	74543
    41943	74499
    41967	74238
    42014	74153
    42070	74109
    42122	73881
    42215	73853
    42223	73780
    42263	73749
    42316	73714
    42332	73680
    42334	73651
    42352	73420
    42418	73394
    42424	73380
    42449	73333
    42450	73328
    42463	73291
    42484	73171
    42514	73113
    42541	73026
    42572	72965
    42573	72842
    42630	72697
    42661	72636
    42725	72595
    42815	72481
    42837	72469
    42874	72385
    42922	72212
    42972	72203
    42977	72148
    43018	72041
    43021	72018
    43042	71982
    43056	71932
    43112	71892
    43113	71787
    43144	71726
    43187	71707
    43208	71685
    43224	71677
    43239	71657
    43260	71489
    43309	71438
    43371	71360
    43405	71267
    43454	71216
    43458	71074
    43525	71072
    43554	70765
    43665	70636
    43679	70634
    43710	70573
    43761	70485
    43768	70305
    43799	70244
    43879	70176
    43910	70115
    43988	70035
    44007	70030
    44010	69944
    44037	69855
    44120	69837
    44180	69785
    44211	69724
    44230	69674
    44244	69575
    44251	69395
    44282	69334
    44344	69286
    44362	69266
    44393	69205
    44440	68977
    44524	68973
    44553	68878
    44560	68870
    44584	68817
    44656	68561
    44767	68432
    44827	68376
    44893	68314
    44923	68067
    44989	68005
    45036	67968
    45043	67960
    45067	67907
    45139	67651
    45250	67522
    45349	67416
    45357	67411
    45376	67404
    45381	67290
    45424	67191
    45446	67082
    45542	66773
    45746	66744
    45822	66522
    45832	66506
    45851	66472
    45922	66335
    45929	66172
    46025	65863
    46305	65612
    46334	65562
    46437	65343
    46613	65210
    46717	65092
    46746	65042
    46827	65004
    46885	64987
    46921	64643
    47117	64522
    47179	64468
    47230	64342
    47247	64272
    47333	64123
    47452	63785
    47618	63725
    47669	63609
    47781	63479
    47864	63265
    48005	63124
    48081	63089
    48101	62815
    48313	62710
    48381	62564
    48410	62514
    48513	62295
    48677	61984
    48739	61951
    48915	61943
    48961	61939
    48965	61823
    48986	61683
    48997	61595
    49089	61464
    49151	61431
    49255	61420
    49304	61373
    49306	61294
    49323	61224
    49398	61163
    49409	61075
    49528	60737
    49735	60704
    49745	60561
    49857	60431
    49940	60217
    50157	60041
    50269	59911
    50293	59786
    50389	59662
    50581	59625
    50602	59485
    50698	59361
    50705	59266
    50892	59189
    50916	59064
    51014	58965
    51149	58903
    51205	58900
    51225	58763
    51323	58748
    51328	58544
    51426	58529
    51572	58484
    51608	58445
    51610	58164
    51827	57988
    52020	57922
    52028	57911
    52131	57887
    52144	57820
    52151	57773
    52205	57577
    52241	57562
    52254	57524
    52350	57418
    52406	57277
    52514	57276
    52551	57118
    52625	57050
    52715	56976
    52805	56954
    52860	56817
    52934	56749
    53036	56708
    53080	56591
    53112	56581
    53200	56566
    53235	56560
    53243	56432
    53276	56414
    53345	56312
    53370	56211
    53403	56187
    53497	56093
    53498	55936
    53643	55777
    53717	55709
    53807	55635
    53897	55613
    53952	55476
    54025	55409
    54026	55408
    54172	55250
    54327	55219
    54334	55108
    54368	55073
    54481	54949
    54642	54896
    54671	54884
    54677	54772
    54720	54720
    54770	54588
    54980	54583
    55029	54419
    55079	54287
    55266	54251
    55344	54163
    55422	54144
    55505	54104
    55525	54026
    55575	53950
    55653	53945
    55674	53895
    55736	53821
    55806	53667
    55983	53594
    56034	53581
    56045	53520
    56094	53506
    56104	53427
    56115	53366
    56288	53365
    56332	53338
    56343	53280
    56393	53272
    56403	53205
    56413	53126
    56464	53110
    56590	53043
    56643	52944
    56679	52929
    56708	52914
    56736	52869
    56798	52812
    56830	52811
    56834	52797
    56838	52719
    56920	52674
    56993	52587
    57045	52568
    57126	52558
    57159	52527
    57169	52467
    57205	52452
    57210	52411
    57229	52373
    57364	52242
    57553	52215
    57578	52117
    57626	52110
    57652	52081
    57748	52078
    57758	52077
    57770	52039
    57818	52036
    57823	52026
    57844	52024
    57864	52021
    57880	52009
    57884	51931
    57888	51882
    57924	51870
    57979	51857
    58018	51852
    58039	51799
    58043	51750
    58129	51732
    58190	51728
    58195	51718
    58210	51672
    58214	51594
    58260	51574
    58288	51556
    58349	51549
    58369	51462
    58410	51454
    58414	51405
    58553	51377
    58581	51327
    58586	51286
    58623	51223
    58740	51117
    58778	51091
    58864	51073
    58911	51062
    58948	51054
    58968	51045
    58972	50967
    58990	50956
    58995	50915
    59079	50900
    59127	50835
    59149	50746
    59339	50700
    59344	50659
    59437	50585
    59498	50490
    59683	50462
    59790	50448
    59807	50416
    59817	50330
    59862	50225
    60017	50093
    60103	50075
    60178	50071
    60181	50016
    60234	49917
    60388	49748
    60552	49671
    60689	49663
    60723	49616
    60800	49543
    60878	49484
    60931	49385
    61085	49216
    61249	49139
    61386	49131
    61392	49072
    61465	49034
    61518	48997
    61587	48985
    61619	48865
    61649	48839
    61741	48816
    61790	48810
    61803	48670
    61974	48615
    62156	48590
    62162	48502
    62215	48465
    62316	48333
    62346	48307
    62500	48138
    62795	47997
    62911	47964
    62966	47942
    63083	47836
    63121	47810
    63193	47808
    63207	47792
    63254	47781
    63283	47673
    63338	47634
    63424	47627
    63454	47618
    63482	47528
    63492	47465
    63608	47432
    63754	47428
    63780	47304
    63980	47141
    64179	46996
    64391	46967
    64490	46879
    64563	46839
    64590	46822
    64645	46802
    64730	46761
    64735	46720
    64868	46677
    64889	46551
    65060	46496
    65088	46435
    65190	46313
    65260	46307
    65287	46290
    65342	46270
    65361	46258
    65427	46229
    65432	46188
    65483	46178
    65586	46019
    65733	45950
    65887	45781
    66055	45763
    66215	45750
    66226	45708
    66323	45707
    66330	45676
    66351	45651
    66381	45576
    66450	45564
    66467	45558
    66531	45541
    66561	45505
    66587	45442
    66593	45441
    66598	45400
    66715	45336
    66741	45273
    66752	45231
    67016	45212
    67048	45119
    67090	45079
    67211	45076
    67283	45037
    67315	44987
    67365	44907
    67595	44899
    67628	44896
    67629	44791
    67759	44738
    67876	44674
    67902	44611
    67913	44569
    68044	44541
    68098	44535
    68198	44487
    68247	44378
    68440	44301
    68462	44262
    68492	44252
    68494	44212
    68643	44138
    68744	44109
    68795	44003
    68917	43997
    68949	43986
    68959	43958
    69114	43957
    69165	43947
    69203	43942
    69211	43933
    69241	43871
    69272	43824
    69318	43822
    69330	43817
    69362	43767
    69364	43749
    69498	43723
    69501	43719
    69538	43692
    69548	43659
    69566	43651
    69591	43646
    69598	43601
    69623	43600
    69634	43557
    69655	43550
    69799	43526
    69804	43476
    69841	43472
    69905	43447
    69956	43341
    70110	43324
    70120	43296
    70184	43271
    70185	43258
    70197	43255
    70284	43153
    70423	43116
    70500	43114
    70516	43051
    70575	43047
    70583	43033
    70650	43025
    70669	42998
    70699	42916
    70715	42906
    70736	42895
    70768	42845
    70843	42841
    70892	42732
    71136	42721
    71173	42716
    71225	42701
    71230	42660
    71244	42610
    71327	42547
    71384	42491
    71530	42431
    71647	42395
    71677	42389
    71736	42385
    71778	42356
    71801	42222
    71918	42200
    71929	42183
    71997	42167
    72053	42070
    72161	42025
    72178	42008
    72227	41899
    72471	41888
    72478	41883
    72519	41835
    72545	41829
    72606	41813
    72630	41769
    72658	41735
    72738	41691
    72787	41582
    72918	41543
    72967	41434
    73136	41402
    73278	41346
    73327	41237
    73595	41235
    73632	41226
    73639	41221
    73655	41124
    73791	41107
    73819	41073
    73829	41066
    73899	41029
    73948	40920
    74079	40881
    74128	40772
    74297	40740
    74420	40697
    74439	40684
    74488	40575
    74756	40573
    74767	40571
    74816	40462
    74990	40404
    75164	40384
    75272	40336
    75298	40290
    75321	40276
    75353	40272
    75452	40261
    75465	40207
    75501	40152
    75532	40144
    75580	40130
    75581	40035
    75845	40016
    75928	39998
    75961	39981
    75977	39889
    76066	39855
    76168	39850
    76180	39781
    76457	39744
    76605	39690
    76618	39660
    76725	39648
    76757	39644
    76774	39539
    76806	39535
    76905	39524
    76928	39487
    76954	39415
    77073	39405
    77181	39364
    77269	39363
    77272	39336
    77280	39297
    77329	39188
    77519	39118
    77669	39095
    77699	39089
    77767	39070
    77860	39056
    77880	39048
    77957	38989
    78149	38950
    78151	38850
    78424	38840
    78442	38824
    78445	38770
    78566	38702
    78653	38677
    78702	38568
    78821	38558
    78847	38541
    78972	38503
    79002	38497
    79011	38488
    79021	38394
    79051	38388
    79333	38311
    79510	38286
    79517	38283
    79531	38252
    79640	38164
    79821	38127
    79858	38123
    79880	38072
    80120	38019
    80124	37981
    80194	37938
    80220	37921
    80339	37911
    80351	37900
    80430	37846
    80479	37737
    80645	37715
    80825	37681
    80913	37669
    80943	37572
    80992	37463
    81308	37421
    81343	37391
    81388	37358
    81481	37355
    81547	37335
    81645	37316
    81668	37272
    81694	37207
    81821	37147
    81971	37107
    81977	37064
    82155	37060
    82212	37055
    82232	37009
    82402	36987
    82435	36942
    82484	36833
    82676	36794
    82800	36791
    82835	36761
    82880	36728
    82897	36715
    83039	36705
    83102	36628
    83186	36577
    83276	36572
    83308	36551
    83313	36517
    83417	36512
    83419	36437
    83469	36434
    83642	36370
    83723	36347
    83725	36286
    83894	36199
    84008	36143
    84237	36117
    84263	36088
    84286	36008
    84561	36004
    84594	35998
    84626	35991
    84684	35952
    84693	35934
    84775	35900
    84784	35897
    84829	35828
    84911	35807
    84928	35794
    85114	35791
    85134	35740
    85215	35717
    85217	35656
    85339	35630
    85386	35569
    85500	35513
    85673	35449
    85778	35378
    85887	35365
    85925	35278
    86205	35265
    86268	35196
    86317	35087
    86746	35060
    86806	34979
    86993	34896
    87145	34870
    87165	34819
    87368	34757
    87379	34735
    87417	34648
    87650	34630
    87760	34566
    87809	34457
    88042	34439
    88177	34402
    88268	34374
    88298	34349
    88485	34266
    88637	34240
    88671	34226
    88870	34222
    88875	34218
    88944	34183
    88950	34181
    88980	34158
    89029	34049
    89262	34031
    89281	34000
    89342	33990
    89488	33966
    89495	33961
    89528	33954
    89624	33918
    89673	33809
    89887	33770
    90110	33766
    90132	33726
    90259	33654
    90362	33595
    90535	33578
    90684	33558
    90705	33513
    90754	33404
    91107	33362
    91206	33342
    91243	33296
    91430	33213
    91582	33187
    91751	33122
    91925	33105
    91974	32996
    92226	32947
    92287	32937
    92506	32934
    92548	32910
    92569	32865
    92618	32756
    92963	32746
    93115	32720
    93284	32655
    93416	32613
    93450	32599
    93507	32529
    93759	32480
    94039	32467
    94079	32463
    94081	32443
    94102	32398
    94151	32289
    94612	32241
    94670	32191
    94872	32189
    94873	32151
    94922	32142
    95059	32106
    95211	32080
    95265	32060
    95314	31951
    95603	31889
    95855	31840
    95916	31830
    96112	31808
    96177	31803
    96198	31758
    96247	31649
    96592	31639
    96694	31599
    96913	31548
    97007	31540
    97079	31492
    97136	31422
    97307	31388
    97388	31373
    97569	31346
    97680	31327
    97731	31291
    97780	31182
    98227	31132
    98299	31084
    98551	31035
    98791	31030
    98831	31022
    98840	30921
    98943	30844
    99284	30810
    99390	30794
    99611	30774
    99623	30771
    99731	30760
    99849	30752
    99858	30698
    99954	30692
    100003	30583
    100344	30549
    100376	30522
    100683	30510
    100717	30488
    100904	30487
    100972	30469
    101021	30360
    101362	30326
    101688	30299
    101701	30287
    101826	30281
    102029	30265
    102042	30253
    102067	30230
    102170	30153
    102511	30119
    102617	30103
    102800	30080
    102956	30072
    102958	30069
    103059	29995
    103230	29892
    103571	29858
    103603	29831
    103860	29819
    103944	29797
    104119	29734
    104248	29669
    104589	29635
    104816	29599
    104878	29596
    105053	29590
    105137	29511
    105447	29486
    105478	29477
    105804	29450
    105834	29376
    106175	29342
    106336	29328
    106501	29315
    106517	29272
    106858	29238
    107033	29193
    107406	29114
    107716	29089
    107747	29080
    107847	29065
    108073	29053
    108103	28979
    108363	28968
    108444	28945
    108492	28903
    108833	28869
    109060	28833
    109122	28830
    109297	28824
    109365	28803
    109381	28745
    109691	28720
    109722	28711
    110048	28684
    110062	28668
    110078	28610
    110419	28576
    110582	28569
    110745	28549
    110768	28542
    110912	28529
    111109	28508
    111129	28464
    111277	28427
    111554	28400
    111657	28384
    111826	28329
    112168	28276
    112354	28249
    112601	28224
    112695	28215
    112781	28208
    112942	28190
    113003	28186
    113025	28146
    113405	28103
    113450	28094
    113478	28073
    113644	28066
    113800	28041
    113830	28039
    113981	28037
    113985	28032
    114048	28023
    114095	27932
    114444	27915
    114624	27914
    114645	27911
    114691	27890
    114697	27889
    114728	27860
    114883	27829
    115041	27807
    115114	27783
    115357	27756
    115373	27698
    115992	27672
    116040	27637
    116054	27621
    116070	27563
    116411	27529
    116572	27515
    116737	27502
    117004	27499
    117159	27468
    117210	27444
    117253	27438
    117269	27380
    117463	27364
    117649	27337
    117936	27319
    118160	27229
    118346	27202
    118501	27195
    118687	27168
    118773	27161
    119013	27141
    119206	27138
    119300	27110
    119359	27046
    119470	27026
    119545	27019
    119739	27003
    119811	26992
    120026	26985
    120040	26976
    120080	26969
    120137	26965
    120212	26958
    120225	26947
    120436	26868
    120581	26846
    120669	26843
    120777	26834
    120922	26812
    121083	26798
    121239	26793
    121248	26785
    121308	26784
    121336	26782
    121576	26749
    121635	26685
    121780	26663
    122005	26649
    122302	26624
    122447	26602
    122672	26588
    122726	26532
    122945	26521
    123067	26498
    123228	26484
    123393	26471
    123708	26470
    123716	26466
    123717	26457
    123763	26455
    123827	26446
    123866	26413
    123925	26349
    124150	26335
    124377	26334
    124467	26333
    124476	26328
    124592	26288
    124817	26274
    124938	26266
    125026	26263
    125065	26230
    125186	26217
    125235	26185
    125567	26175
    125666	26150
    125862	26143
    125902	26124
    125992	26105
    126137	26083
    126375	26066
    126578	26031
    126766	25992
    126976	25986
    126991	25978
    127083	25952
    127302	25941
    127308	25938
    127424	25918
    127649	25904
    127750	25891
    127888	25867
    128076	25828
    128282	25769
    128507	25755
    128734	25754
    128824	25753
    128949	25708
    129174	25694
    129422	25650
    129592	25605
    130023	25570
    130248	25556
    130259	25544
    130732	25486
    131333	25406
    132159	25358
    132348	25353
    132590	25323
    132779	25318
    132826	25297
    132908	25296
    133015	25292
    133299	25239
    133488	25234
    133900	25159
    134089	25154
    134661	25147
    134719	25104
    135134	25089
    135346	25071
    135545	25056
    135582	25045
    135664	25044
    135735	25009
    136055	24987
    136561	24961
    136656	24907
    137228	24900
    137286	24857
    137701	24842
    137890	24837
    138089	24832
    138222	24827
    138302	24762
    138491	24757
    138823	24747
    139121	24707
    139453	24697
    139735	24687
    139748	24674
    139947	24659
    139984	24648
    140066	24647
    140378	24624
    140457	24590
    141058	24510
    141688	24460
    142420	24455
    142491	24435
    142523	24430
    142761	24412
    143121	24385
    143596	24382
    143853	24380
    143956	24355
    144655	24353
    144688	24350
    145015	24326
    145205	24322
    145565	24295
    146040	24292
    146400	24265
    147459	24236
    147934	24233
    148294	24206
    148835	24202
    149195	24175
    150113	24172
    150520	24169
    150729	24143
    151089	24116
    152007	24113
    152414	24110
    153223	24100
    153478	24097
    153583	24073
    154501	24070
    154908	24067
    155826	24064
    155972	24054
    156890	24051
    157297	24048
    158215	24045
    159691	24041
    160609	24038
    161016	24035
    161934	24032"""
    n = 1721 - 3 + 1
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        coords[i, 0] = int(next(it))
        coords[i, 1] = int(next(it))
    return coords

# %%
def euclidCD100():
    coords_string= """25372	165188
    25377	164997
    25415	162061
    25420	161870
    25459	160791
    25462	160459
    25467	160268
    25473	160122
    25506	159189
    25511	158998
    25515	158711
    25520	158520
    25559	157441
    25564	157250
    25592	157114
    25597	156923
    25622	156599
    25627	156408
    25643	156125
    25648	155934
    25658	155864
    25675	155591
    25691	155512
    25706	155283
    25707	154852
    25714	154512
    25719	154321
    25752	153994
    25789	153953
    25791	153536
    25798	153196
    25803	153005
    25836	152678
    25846	152583
    25862	151923
    25895	151596
    25941	151328
    25944	151024
    25946	150607
    25979	150280
    25989	150185
    26022	149858
    26048	149650
    26068	149590
    26089	149581
    26091	149164
    26122	149082
    26123	149078
    26124	148837
    26125	148661
    26141	148611
    26156	148556
    26158	148334
    26168	148239
    26184	148189
    26199	148134
    26201	147912
    26216	147696
    26236	147617
    26249	147369
    26269	147290
    26270	147218
    26279	147195
    26286	147168
    26295	147101
    26303	146891
    26312	146868
    26313	146796
    26318	146739
    26320	146665
    26338	146660
    26346	146469
    26351	146412
    26353	146338
    26361	146253
    26363	146243
    26381	146238
    26387	146022
    26394	145926
    26395	145750
    26415	145671
    26426	145645
    26428	145423
    26448	145344
    26458	145249
    26465	145222
    26474	145155
    26489	145065
    26491	144922
    26497	144793
    26506	144706
    26528	144688
    26530	144466
    26539	144379
    26540	144307
    26571	144202
    26573	143980
    26593	143965
    26601	143949
    26604	143875
    26608	143749
    26610	143675
    26634	143622
    26641	143422
    26642	143350
    26643	143348
    26653	143253
    26673	143245
    26674	143243
    26675	143023
    26685	142760
    26712	142718
    26716	142655
    26718	142433
    26745	142391
    26749	142328
    26755	142296
    26764	142165
    26779	142075
    26787	141803
    26818	141698
    26820	141476
    26851	141371
    26866	141208
    26877	141088
    26899	140881
    26910	140761
    26937	140719
    26947	140624
    26956	140493
    26971	140403
    26979	140131
    27012	139804
    27057	139680
    27058	139536
    27065	139408
    27091	139209
    27098	139081
    27128	138987
    27144	138813
    27161	138660
    27177	138486
    27207	138392
    27208	138367
    27218	138272
    27240	138065
    27251	137945
    27277	137737
    27297	137677
    27310	137410
    27320	137315
    27351	137302
    27353	136988
    27389	136815
    27396	136687
    27406	136592
    27432	136393
    27439	136265
    27475	136092
    27485	135997
    27510	135957
    27518	135670
    27543	135630
    27560	135474
    27572	135409
    27589	135388
    27596	135234
    27614	135102
    27629	134907
    27639	134879
    27647	134775
    27650	134759
    27675	134665
    27693	134533
    27711	134401
    27713	134342
    27719	134129
    27752	133802
    27792	133747
    27797	133678
    27798	133534
    27805	133406
    27831	133207
    27838	133079
    27884	132811
    27917	132484
    27963	132435
    27965	132241
    28008	131940
    28018	131812
    28033	131757
    28044	131646
    28051	131518
    28097	131217
    28112	131162
    28120	131149
    28123	131042
    28130	130923
    28181	130801
    28184	130662
    28186	130625
    28192	130412
    28224	130379
    28225	130085
    28259	130028
    28270	129961
    28271	129817
    28278	129689
    28304	129490
    28311	129362
    28357	129094
    28390	128767
    28438	128524
    28474	128351
    28481	128223
    28491	128128
    28517	127929
    28524	127801
    28570	127533
    28603	127206
    28646	127034
    28657	126945
    28699	126638
    28714	126443
    28732	126311
    28778	126069
    28835	126023
    28836	125944
    28868	125836
    28878	125575
    28885	125447
    28905	125314
    28931	125179
    28938	124987
    28964	124852
    28984	124745
    28991	124591
    29024	124264
    29065	124213
    29070	124022
    29091	124014
    29098	123886
    29134	123713
    29144	123618
    29169	123578
    29177	123291
    29202	123251
    29220	123119
    29231	123030
    29248	123009
    29255	122855
    29273	122723
    29288	122528
    29306	122396
    29334	122286
    29352	122154
    29387	122092
    29410	122029
    29434	122025
    29441	121831
    29456	121787
    29479	121399
    29512	121072
    29558	120830
    29565	120676
    29598	120349
    29644	120107
    29698	120088
    29717	120008
    29744	119846
    29772	119800
    29780	119741
    29783	119730
    29787	119621
    29805	119473
    29813	119414
    29835	119379
    29848	119270
    29851	119231
    29881	119137
    29920	119102
    29934	119090
    29938	118884
    29953	118775
    29979	118666
    29980	118542
    29993	118531
    30010	118507
    30013	118215
    30043	118180
    30058	118071
    30059	117973
    30066	117819
    30099	117492
    30145	117250
    30199	117231
    30218	117151
    30236	117149
    30245	116989
    30273	116943
    30281	116884
    30284	116873
    30288	116764
    30306	116616
    30314	116557
    30336	116522
    30349	116413
    30352	116374
    30382	116280
    30421	116245
    30435	116233
    30439	116027
    30454	115918
    30480	115809
    30511	115650
    30521	115510
    30527	115491
    30544	115323
    30559	115214
    30625	115183
    30632	114996
    30654	114980
    30657	114906
    30696	114891
    30701	114798
    30704	114619
    30715	114590
    30736	114575
    30737	114292
    30759	114276
    30796	114244
    30810	114193
    30820	114095
    30835	113984
    30843	113975
    30857	113968
    30876	113936
    30879	113876
    30893	113668
    30911	113637
    30925	113391
    30966	113341
    30981	113232
    30998	113173
    31016	113142
    31042	113108
    31050	113099
    31054	113014
    31076	112998
    31079	112924
    31088	112765
    31103	112469
    31121	112438
    31159	112310
    31181	112294
    31218	112262
    31219	112130
    31229	112115
    31242	112113
    31246	112061
    31257	112002
    31265	111993
    31277	111814
    31310	111593
    31328	111562
    31347	111409
    31370	111216
    31405	111199
    31416	110974
    31478	110916
    31487	110615
    31525	110487
    31543	110456
    31584	110439
    31585	110281
    31611	109873
    31657	109631
    31710	109445
    31782	109374
    31783	109346
    31792	109234
    31815	109047
    31818	108997
    31826	108938
    31848	108903
    31864	108755
    31879	108752
    31894	108661
    31909	108633
    31917	108569
    31951	108408
    32004	108222
    32022	108171
    32033	107891
    32056	107704
    32079	107649
    32109	107518
    32132	107463
    32149	107356
    32202	107170
    32222	107163
    32237	107065
    32248	106956
    32263	106828
    32293	106734
    32310	106722
    32316	106642
    32346	106548
    32356	106480
    32371	106477
    32373	106426
    32409	106294
    32426	106240
    32439	106200
    32443	106133
    32463	106111
    32474	106095
    32478	105722
    32525	105616
    32531	105536
    32548	105429
    32571	105374
    32601	105243
    32624	105188
    32674	105144
    32693	105048
    32714	104888
    32715	104752
    32740	104681
    32755	104553
    32785	104459
    32808	104367
    32838	104273
    32861	104218
    32865	104151
    32908	103942
    32951	103918
    32961	103756
    32970	103447
    33023	103261
    33102	103181
    33132	103169
    33145	102972
    33198	102786
    33207	102477
    33260	102291
    33314	102260
    33367	102074
    33389	101960
    33437	101775
    33490	101589
    33544	101569
    33551	101290
    33596	101237
    33604	101104
    33626	100990
    33674	100805
    33727	100619
    33763	100603
    33781	100588
    33793	100509
    33816	100454
    33819	100124
    33928	100032
    33944	99955
    33951	99858
    33975	99824
    33978	99497
    34056	99154
    34165	99062
    34204	99045
    34215	98527
    34286	98452
    34324	98435
    34328	98294
    34393	98246
    34418	98186
    34441	98075
    34445	97825
    34523	97482
    34636	97438
    34665	97386
    34671	97373
    34682	96855
    34795	96622
    34860	96574
    34897	96566
    34908	96403
    34944	96393
    34987	96129
    35008	96128
    35033	96059
    35048	95950
    35100	95910
    35103	95766
    35132	95714
    35182	95317
    35322	95294
    35341	95014
    35356	94905
    35364	94894
    35454	94457
    35500	94387
    35515	94278
    35567	94238
    35590	94109
    35628	94045
    35693	93785
    35732	93702
    35853	93656
    35875	93368
    35907	93295
    35936	93189
    36028	93173
    36041	93068
    36044	92989
    36049	92956
    36050	92870
    36066	92776
    36118	92750
    36135	92579
    36164	92575
    36182	92426
    36197	92317
    36277	92247
    36283	92200
    36296	92127
    36306	92113
    36310	92098
    36355	91901
    36370	91792
    36374	91623
    36423	91532
    36511	91317
    36526	91208
    36580	91146
    36629	91083
    36631	90903
    36687	90813
    36723	90780
    36765	90726
    36771	90611
    36773	90441
    36833	90439
    36861	90232
    36916	90075
    37025	89983
    37052	89949
    37085	89812
    37109	89581
    37129	89550
    37130	89522
    37148	89290
    37157	89245
    37190	89108
    37278	89107
    37346	88974
    37383	88403
    37573	88297
    37628	88225
    37663	88065
    37702	88056
    37707	87966
    37750	87774
    37766	87592
    37856	87360
    37891	87337
    37919	87307
    37946	87133
    38016	86926
    38082	86815
    38091	86770
    38122	86729
    38124	86633
    38194	86455
    38317	85928
    38471	85916
    38507	85822
    38547	85802
    38562	85693
    38579	85656
    38597	85590
    38636	85581
    38650	85568
    38664	85211
    38700	85117
    38760	85094
    38790	84885
    38825	84862
    38853	84832
    38880	84658
    38950	84451
    39047	84400
    39056	84254
    39128	83980
    39227	83941
    39282	83927
    39297	83734
    39333	83640
    39342	83629
    39353	83615
    39403	83537
    39439	83443
    39449	83433
    39458	83385
    39475	83263
    39496	83218
    39511	83169
    39584	83093
    39601	82937
    39664	82915
    39679	82728
    39694	82619
    39756	82608
    39761	82503
    39843	82501
    39856	82359
    39935	82167
    39990	82088
    40026	82078
    40029	82035
    40036	82026
    40041	81902
    40093	81707
    40108	81598
    40211	81516
    40232	81505
    40247	81396
    40291	81247
    40395	81145
    40402	81039
    40440	80990
    40450	80946
    40455	80881
    40492	80835
    40560	80810
    40573	80793
    40579	80788
    40594	80679
    40630	80585
    40638	80530
    40667	80411
    40706	80392
    40720	80353
    40726	80278
    40741	80266
    40780	80213
    40830	80091
    40865	80028
    40875	80024
    40880	79919
    40923	79903
    40950	79901
    40965	79792
    40994	79739
    41014	79694
    41035	79649
    41044	79610
    41047	79479
    41063	79477
    41083	79469
    41110	79467
    41120	79371
    41125	79358
    41140	79354
    41155	79245
    41191	79235
    41201	79124
    41228	79122
    41243	79013
    41311	78988
    41324	78971
    41338	78894
    41374	78884
    41389	78853
    41393	78821
    41394	78762
    41410	78760
    41413	78736
    41430	78668
    41462	78565
    41477	78456
    41548	78407
    41575	78405
    41580	78374
    41584	78313
    41590	78296
    41626	78202
    41641	78143
    41660	78105
    41674	78081
    41701	78079
    41716	77970
    41771	77936
    41780	77889
    41786	77827
    41798	77657
    41834	77647
    41861	77645
    41876	77536
    41921	77504
    41957	77494
    41973	77485
    41979	77454
    41988	77426
    41989	77377
    42016	77375
    42021	77364
    42024	77332
    42031	77266
    42063	77253
    42112	77224
    42118	77219
    42127	77172
    42133	77110
    42145	76940
    42181	76846
    42217	76836
    42223	76819
    42259	76725
    42304	76693
    42319	76644
    42362	76643
    42371	76615
    42378	76549
    42432	76299
    42468	76289
    42495	76287
    42510	76178
    42528	76129
    42564	76119
    42583	76041
    42606	76008
    42651	75976
    42666	75927
    42709	75926
    42722	75787
    42729	75786
    42740	75555
    42767	75553
    42782	75444
    42863	75402
    42885	75362
    42930	75324
    42991	75306
    43028	75295
    43044	75264
    43069	75070
    43076	75069
    43087	74838
    43114	74836
    43129	74727
    43210	74685
    43232	74645
    43324	74622
    43366	74606
    43423	74482
    43447	74469
    43463	74417
    43471	74394
    43473	74374
    43487	74334
    43543	74210
    43602	74198
    43610	74181
    43628	74064
    43636	73974
    43670	73953
    43734	73945
    43750	73914
    43751	73911
    43773	73871
    43800	73753
    43820	73657
    43834	73617
    43890	73493
    43957	73464
    44001	73454
    44035	73411
    44071	73401
    44076	73398
    44088	73276
    44115	73222
    44177	73200
    44197	73092
    44232	72998
    44246	72973
    44249	72860
    44320	72763
    44374	72747
    44382	72694
    44423	72681
    44435	72559
    44523	72548
    44533	72530
    44558	72406
    44566	72401
    44585	72374
    44593	72256
    44596	72143
    44694	72114
    44716	72103
    44780	72077
    44822	72046
    44833	71927
    44923	71920
    44925	71768
    44982	71679
    45018	71669
    45075	71513
    45111	71503
    45134	71482
    45137	71369
    45204	71368
    45235	71327
    45246	71288
    45261	71282
    45272	71051
    45329	70962
    45365	70952
    45463	70882
    45509	70835
    45541	70829
    45562	70723
    45594	70694
    45682	70656
    45683	70618
    45687	70610
    45695	70557
    45717	70541
    45728	70415
    45755	70278
    45813	70277
    45854	70268
    45870	70188
    45880	70165
    45888	70112
    45909	70006
    45941	69977
    46043	69967
    46064	69824
    46102	69561
    46236	69522
    46296	69504
    46328	69464
    46381	69447
    46388	69376
    46404	69323
    46408	69310
    46431	69186
    46524	69087
    46538	69049
    46585	68914
    46642	68825
    46643	68787
    46710	68786
    46755	68593
    46778	68469
    46871	68370
    47030	68362
    47057	68355
    47064	68339
    47065	68313
    47079	68275
    47084	68218
    47126	68140
    47177	68119
    47191	68081
    47219	68041
    47251	68012
    47270	67953
    47296	67819
    47319	67695
    47412	67596
    47431	67501
    47524	67402
    47640	67373
    47717	67371
    47718	67345
    47732	67307
    47775	67264
    47789	67220
    47811	67179
    47848	67084
    47865	67032
    47878	67024
    47924	67009
    47945	66937
    47960	66890
    47972	66727
    48065	66628
    48181	66599
    48248	66598
    48258	66597
    48272	66573
    48287	66558
    48293	66405
    48316	66281
    48409	66182
    48465	66128
    48501	66116
    48518	66064
    48531	66056
    48541	65940
    48634	65841
    48789	65824
    48799	65789
    48808	65765
    48834	65631
    48857	65507
    48950	65408
    48969	65313
    49062	65214
    49118	65160
    49194	64972
    49287	64873
    49390	64848
    49403	64844
    49416	64836
    49452	64821
    49498	64702
    49510	64539
    49603	64440
    49723	64361
    49798	64301
    49846	64208
    49886	64197
    49943	64108
    49979	64098
    50011	64069
    50039	63928
    50043	63880
    50056	63876
    50069	63868
    50079	63752
    50172	63653
    50331	63645
    50337	63601
    50379	63596
    50385	63501
    50478	63402
    50492	63364
    50571	63236
    50608	63141
    50664	63101
    50731	62988
    50732	62784
    50825	62685
    50984	62677
    50990	62633
    51083	62534
    51242	62448
    51253	62430
    51261	62173
    51384	62020
    51577	61989
    51579	61904
    51642	61869
    51672	61805
    51831	61797
    51837	61753
    51878	61752
    51883	61672
    51905	61666
    51930	61654
    51996	61636
    52006	61519
    52120	61470
    52135	61466
    52158	61304
    52235	61239
    52281	61151
    52328	61140
    52337	61049
    52508	61040
    52525	60979
    52587	60977
    52595	60898
    52665	60895
    52679	60816
    52687	60763
    52727	60723
    52728	60681
    52773	60502
    52866	60403
    52888	60271
    52981	60172
    53105	60112
    53239	60021
    53350	59976
    53363	59961
    53409	59917
    53469	59872
    53473	59823
    53502	59818
    53510	59770
    53596	59738
    53603	59671
    53618	59655
    53706	59618
    53727	59611
    53829	59465
    54031	59416
    54058	59406
    54065	59359
    54087	59314
    54139	59301
    54179	59290
    54181	59286
    54187	59267
    54201	59239
    54210	59205
    54212	59164
    54240	59154
    54294	59140
    54302	59137
    54304	59133
    54320	59011
    54327	58933
    54443	58858
    54492	58850
    54541	58680
    54664	58527
    54782	58494
    54909	58391
    54922	58376
    55032	58238
    55163	58179
    55188	58167
    55276	58143
    55286	58026
    55312	57941
    55383	57870
    55427	57710
    55498	57639
    55550	57557
    55756	57488
    55795	57421
    55808	57406
    55918	57268
    56049	57209
    56120	57138
    56172	57056
    56315	57029
    56417	56920
    56530	56884
    56540	56767
    56626	56731
    56749	56578
    56856	56543
    56896	56513
    56934	56493
    57007	56427
    57031	56360
    57149	56350
    57163	56223
    57256	56124
    57371	56077
    57402	56035
    57490	56017
    57514	55973
    57525	55882
    57640	55775
    57692	55744
    57783	55731
    57865	55728
    57893	55607
    57907	55601
    57950	55593
    57981	55570
    58104	55417
    58213	55390
    58214	55324
    58337	55171
    58493	55100
    58503	55006
    58640	55000
    58669	54946
    58750	54931
    58761	54855
    58789	54845
    58861	54811
    58920	54624
    59043	54471
    59100	54354
    59223	54201
    59481	54050
    59638	54004
    59700	53968
    59792	53928
    59854	53796
    59977	53643
    60160	53639
    60188	53618
    60235	53492
    60299	53375
    60399	53182
    60522	53029
    60780	52878
    60946	52848
    60999	52796
    61048	52782
    61176	52664
    61244	52660
    61257	52645
    61367	52507
    61487	52446
    61522	52409
    61544	52375
    61598	52203
    61721	52050
    61966	51914
    61979	51899
    62089	51761
    62247	51748
    62347	51610
    62505	51597
    62513	51580
    62574	51458
    62697	51305
    62855	51292
    62955	51154
    63078	51058
    63230	51044
    63312	51027
    63323	50922
    63336	50907
    63446	50769
    63647	50730
    63662	50722
    63704	50618
    63837	50586
    63897	50487
    63931	50466
    63960	50433
    64054	50313
    64203	50279
    64312	50162
    64445	50130
    64461	50128
    64505	50031
    64568	49977
    64783	49950
    64802	49949
    64803	49921
    64826	49826
    65020	49736
    65090	49730
    65092	49697
    65147	49684
    65155	49643
    65268	49606
    65270	49531
    65308	49498
    65368	49399
    65431	49345
    65677	49246
    65689	49194
    65790	49190
    65825	49142
    65948	49129
    66010	49122
    66011	49075
    66045	49040
    66064	48975
    66105	48941
    66168	48887
    66218	48885
    66269	48870
    66277	48833
    66281	48831
    66355	48778
    66370	48740
    66426	48736
    66433	48686
    66434	48640
    66494	48541
    66557	48487
    66776	48431
    66815	48336
    66925	48281
    66985	48182
    67048	48128
    67102	48085
    67165	48031
    67306	47977
    67423	47880
    67533	47825
    67593	47726
    67656	47672
    67875	47649
    67914	47521
    68126	47465
    68130	47448
    68189	47411
    68225	47344
    68388	47297
    68420	47247
    68483	47193
    68558	47143
    68621	47089
    68758	47083
    68816	46992
    68879	46938
    69056	46913
    69091	46882
    69154	46828
    69190	46761
    69349	46731
    69385	46664
    69448	46610
    69625	46589
    69660	46554
    69688	46535
    69723	46500
    69883	46438
    69918	46403
    69946	46384
    69981	46349
    70021	46330
    70136	46280
    70196	46278
    70255	46237
    70259	46224
    70290	46177
    70394	46129
    70442	46070
    70554	46069
    70646	46066
    70647	46050
    70664	46041
    70687	45934
    70747	45835
    70810	45781
    71014	45777
    71056	45775
    71077	45723
    71240	45660
    71255	45594
    71300	45561
    71363	45507
    71415	45506
    71517	45500
    71622	45493
    71642	45472
    71676	45469
    71682	45448
    71685	45439
    71739	45415
    71757	45385
    71788	45333
    71808	45320
    71860	45319
    71931	45296
    71943	45273
    71956	45265
    72019	45211
    72086	45172
    72211	45144
    72217	45140
    72312	45135
    72330	45105
    72341	45059
    72393	45051
    72412	45043
    72475	44989
    72572	44937
    72624	44936
    72711	44903
    72746	44902
    72773	44898
    72790	44809
    72921	44807
    73023	44805
    73058	44803
    73069	44755
    73075	44750
    73114	44721
    73132	44701
    73150	44667
    73238	44647
    73279	44641
    73323	44548
    73343	44535
    73395	44534
    73417	44528
    73496	44487
    73546	44399
    73703	44393
    73755	44392
    73784	44349
    73847	44295
    73876	44274
    73928	44273
    73970	44254
    74022	44253
    74049	44213
    74079	44138
    74099	44125
    74151	44124
    74293	44113
    74372	44086
    74389	44041
    74400	43999
    74463	43945
    74610	43907
    74632	43864
    74684	43863
    74821	43848
    74846	43839
    74898	43838
    74925	43790
    74942	43767
    74953	43725
    74976	43724
    75016	43671
    75068	43670
    75163	43633
    75215	43632
    75302	43595
    75365	43541
    75530	43515
    75546	43505
    75593	43461
    75609	43451
    75661	43450
    75740	43423
    75748	43413
    75802	43396
    75811	43359
    75865	43342
    75918	43313
    75965	43302
    76065	43275
    76109	43268
    76145	43264
    76172	43214
    76208	43210
    76227	43196
    76234	43193
    76275	43161
    76336	43147
    76350	43121
    76410	43042
    76535	43014
    76737	43006
    76764	42930
    76827	42876
    76967	42849
    77030	42795
    77063	42786
    77126	42732
    77224	42723
    77287	42669
    77391	42650
    77434	42631
    77483	42603
    77535	42602
    77603	42597
    77630	42556
    77666	42543
    77714	42539
    77721	42507
    77812	42460
    77880	42449
    77971	42416
    78015	42375
    78031	42337
    78156	42309
    78282	42222
    78345	42168
    78492	42130
    78687	42077
    78834	42039
    78870	42029
    78877	41997
    78912	41938
    78964	41937
    79087	41905
    79099	41885
    79267	41862
    79272	41854
    79346	41838
    79366	41827
    79415	41813
    79478	41759
    79541	41742
    79561	41730
    79624	41676
    79636	41670
    79792	41656
    79844	41650
    79856	41644
    79875	41606
    79938	41552
    80080	41544
    80085	41514
    80141	41474
    80170	41436
    80206	41419
    80400	41397
    80442	41350
    80463	41343
    80529	41333
    80666	41265
    80799	41240
    80838	41237
    80885	41223
    80905	41210
    80948	41146
    81011	41092
    81102	41015
    81369	41005
    81385	40999
    81425	40929
    81509	40879
    81594	40866
    81635	40754
    81918	40738
    81958	40668
    82241	40652
    82264	40558
    82493	40528
    82587	40472
    82632	40427
    82823	40402
    82852	40364
    82888	40347
    82955	40341
    82963	40321
    83039	40291
    83145	40271
    83165	40166
    83436	40154
    83488	40080
    83630	40074
    83693	40020
    83784	39943
    84034	39848
    84161	39765
    84317	39682
    84484	39679
    84600	39666
    84640	39596
    84790	39569
    84946	39486
    85113	39483
    85268	39472
    85269	39400
    85424	39389
    85425	39361
    85564	39260
    85824	39258
    85853	39201
    85862	39198
    85910	39190
    85916	39147
    86027	39120
    86183	39037
    86327	39000
    86483	38917
    86560	38859
    86716	38776
    86976	38774
    86999	38760
    87042	38752
    87070	38693
    87189	38663
    87345	38580
    87605	38578
    87628	38564
    87697	38559
    87699	38497
    87847	38496
    87853	38476
    88003	38413
    88105	38375
    88202	38365
    88261	38292
    88482	38280
    88601	38277
    88615	38209
    88669	38135
    88868	38102
    88890	38096
    88969	38015
    89202	37874
    89462	37872
    89485	37858
    89598	37819
    89753	37808
    89831	37678
    90091	37676
    90114	37662
    90362	37623
    90413	37618
    90489	37511
    90747	37390
    91007	37388
    91118	37315
    91331	37296
    91376	37194
    91576	37140
    91859	37124
    91960	37100
    92023	37046
    92034	37027
    92205	36944
    92455	36943
    92488	36928
    92593	36828
    92853	36826
    92860	36744
    93121	36656
    93222	36632
    93437	36619
    93489	36548
    93739	36547
    93750	36460
    93981	36443
    94014	36439
    94066	36423
    94129	36369
    94151	36344
    94216	36314
    94373	36312
    94405	36260
    94667	36229
    94708	36209
    94780	36148
    94845	36118
    94967	36094
    95034	36064
    95337	36013
    95459	35989
    95526	35959
    95559	35955
    95596	35898
    95761	35830
    95918	35828
    95997	35782
    96140	35739
    96251	35698
    96390	35634
    96626	35586
    96769	35543
    96880	35502
    97037	35486
    97193	35459
    97261	35438
    97372	35397
    97405	35393
    97503	35381
    97567	35355
    97607	35268
    97764	35266
    97863	35265
    97890	35252
    97984	35251
    98017	35220
    98047	35197
    98099	35163
    98196	35159
    98236	35072
    98492	35069
    98519	35056
    98688	35054
    98692	35030
    98728	34967
    98923	34925
    99048	34897
    99205	34895
    99234	34854
    99415	34820
    99457	34775
    99552	34729
    99677	34701
    99863	34658
    100044	34624
    100086	34579
    100346	34577
    100364	34556
    100447	34555
    100492	34532
    100501	34465
    100684	34437
    100901	34410
    100931	34370
    100993	34360
    101100	34337
    101176	34332
    101221	34323
    101284	34269
    101423	34265
    101487	34238
    101540	34232
    101559	34210
    101560	34174
    101729	34141
    101779	34136
    101949	34110
    102001	34083
    102052	34069
    102064	34029
    102110	33973
    102556	33924
    102630	33887
    102693	33833
    102739	33777
    102999	33775
    103022	33761
    103109	33733
    103159	33728
    103231	33672
    103386	33670
    103488	33656
    103551	33602
    103571	33544
    103738	33537
    103788	33532
    103854	33528
    103921	33509
    103960	33480
    104063	33439
    104180	33406
    104200	33348
    104460	33346
    104483	33332
    104589	33284
    104692	33243
    104887	33201
    105081	33179
    105184	33176
    105224	33174
    105238	33155
    105289	33141
    105301	33101
    105347	33045
    105397	33040
    105516	33005
    105776	33003
    105793	32996
    105799	32989
    105806	32918
    105930	32905
    105976	32849
    106026	32844
    106259	32833
    106298	32813
    106396	32800
    106435	32722
    106695	32720
    106718	32706
    106788	32674
    106808	32616
    107025	32604
    107091	32600
    107197	32552
    107300	32511
    107417	32478
    107437	32420
    107697	32418
    107720	32404
    107826	32356
    107929	32315
    108124	32273
    108318	32251
    108421	32248
    108461	32246
    108569	32218
    108603	32208
    108616	32168
    108634	32112
    108753	32077
    109013	32075
    109036	32061
    109043	31990
    109245	31972
    109263	31916
    109523	31914
    109535	31885
    109672	31794
    109932	31792
    109955	31778
    110164	31689
    110424	31687
    110447	31673
    110524	31671
    110585	31669
    110656	31622
    110860	31612
    110933	31549
    110994	31547
    111148	31517
    111358	31499
    111425	31444
    111486	31442
    111708	31428
    111725	31411
    111850	31394
    111857	31369
    111965	31368
    111974	31360
    111977	31337
    112003	31330
    112124	31299
    112134	31289
    112197	31263
    112329	31221
    112432	31210
    112569	31198
    112579	31172
    112606	31141
    112652	31136
    112695	31086
    112756	31084
    112888	31042
    113061	31014
    113104	30964
    113165	30962
    113387	30948
    113448	30946
    113529	30914
    113553	30909
    113596	30859
    113657	30857
    113879	30843
    113889	30839
    113896	30826
    114014	30824
    114021	30797
    114028	30784
    114136	30783
    114148	30752
    114272	30751
    114291	30744
    114295	30714
    114305	30704
    114368	30678
    114500	30636
    114681	30629
    114777	30556
    114933	30541
    114992	30531
    115173	30524
    115210	30461
    115269	30451
    115425	30436
    115552	30435
    115606	30422
    115702	30356
    115883	30342
    115942	30332
    116098	30317
    116295	30300
    116375	30237
    116658	30221
    116703	30196
    116847	30193
    116907	30183
    116980	30116
    117195	30091
    117199	30077
    117375	30074
    117380	30070
    117472	30011
    117476	29997
    117632	29982
    117691	29972
    117867	29969
    117872	29965
    117909	29902
    117968	29892
    118124	29877
    118305	29863
    118364	29853
    118401	29797
    118582	29783
    118641	29773
    118797	29758
    119044	29749
    119074	29678
    119402	29637
    119547	29634
    119606	29624
    119679	29557
    119894	29532
    120039	29529
    120074	29515
    120171	29452
    120472	29447
    120566	29410
    120691	29394
    120906	29369
    121105	29359
    121178	29352
    121183	29289
    121382	29279
    121567	29250
    121747	29219
    121844	29170
    122024	29139
    122180	29124
    122239	29114
    122336	29065
    122457	29044
    122516	29034
    122672	29019
    122874	29011
    122949	28939
    123250	28934
    123366	28906
    123547	28892
    123592	28891
    123645	28862
    123848	28835
    123978	28834
    123986	28803
    124039	28787
    124213	28779
    124298	28762
    124345	28737
    124423	28712
    124555	28670
    124622	28657
    124832	28590
    125047	28565
    125114	28552
    125324	28485
    125625	28480
    125810	28475
    125967	28437
    126151	28416
    126311	28405
    126368	28399
    126515	28361
    126584	28350
    126588	28325
    126720	28283
    126997	28203
    127212	28178
    127489	28098
    127790	28093
    128073	28090
    128120	28084
    128221	28083
    128257	28068
    128335	28059
    128472	28043
    128612	27979
    128749	27963
    129050	27958
    129249	27914
    129256	27905
    129281	27893
    129437	27884
    129445	27881
    129738	27879
    129746	27876
    129872	27844
    130173	27839
    130264	27838
    130372	27795
    130379	27786
    130404	27774
    130516	27770
    130541	27758
    130697	27749
    130705	27746
    130998	27744
    131006	27741
    131013	27727
    131041	27709
    131048	27700
    131205	27697
    131222	27688
    131229	27679
    131237	27676
    131560	27660
    131639	27651
    131664	27639
    131820	27630
    131828	27627
    132121	27625
    132129	27622
    132164	27590
    132171	27581
    132301	27574
    132308	27565
    132352	27560
    132360	27557
    132482	27553
    132489	27544
    132497	27541
    132780	27534
    132805	27522
    132961	27513
    132969	27510
    132997	27492
    133178	27471
    133327	27467
    133352	27455
    133431	27446
    133516	27443
    133605	27434
    133612	27425
    133620	27422
    133977	27415
    133985	27412
    134033	27408
    134040	27399
    134065	27387
    134120	27373
    134257	27357
    134301	27352
    134438	27336
    134572	27329
    134612	27320
    134746	27317
    134753	27308
    134761	27305
    135056	27301
    135081	27289
    135112	27271
    135119	27262
    135276	27259
    135293	27250
    135300	27241
    135308	27238
    135561	27217
    135769	27210
    135777	27207
    135825	27203
    135832	27194
    135989	27191
    136006	27182
    136013	27173
    136021	27170
    136372	27136
    136379	27127
    136521	27121
    136553	27115
    136560	27106
    136568	27103
    136702	27100
    136848	27096
    137005	27093
    137022	27084
    137029	27075
    137037	27072
    137068	27054
    137249	27033
    137537	27023
    137718	27002
    137781	26986
    137962	26965
    138236	26961
    138328	26919
    138509	26898
    138797	26888
    138978	26867
    139315	26847
    139496	26826
    139605	26818
    139954	26788
    140275	26778
    140361	26776
    140399	26753
    140406	26744
    140414	26741
    140748	26738
    140788	26716
    140882	26707
    141063	26686
    141351	26676
    141460	26671
    141461	26670
    141479	26667
    141491	26663
    141532	26655
    141535	26643
    141621	26641
    141684	26639
    141704	26626
    141716	26622
    141802	26620
    142008	26603
    142050	26601
    142132	26600
    142144	26596
    142149	26591
    142156	26582
    142164	26579
    142168	26578
    142176	26575
    142339	26574
    142355	26536
    142739	26532
    142751	26528
    142799	26527
    142845	26509
    142857	26505
    143191	26484
    143374	26480
    143470	26464
    143480	26457
    143538	26434
    143924	26395
    143936	26391
    144105	26374
    144117	26370
    144434	26357
    144451	26349
    144559	26343
    144740	26322
    145288	26272
    145300	26268
    145617	26255
    145634	26247
    145923	26220
    146375	26217
    146379	26216
    146387	26213
    146467	26205
    146605	26198
    146711	26175
    146950	26170
    146962	26166
    147010	26165
    147056	26147
    147068	26143
    147402	26122
    147505	26113
    147570	26111
    147691	26095
    147749	26072
    147790	26061
    147971	26040
    148135	26033
    148147	26029
    148316	26012
    148328	26008
    148645	25995
    148662	25987
    148770	25981
    148951	25960
    148973	25959
    149154	25938
    149318	25931
    149330	25927
    149499	25910
    149511	25906
    149828	25893
    149845	25885
    149953	25879
    150134	25858
    150635	25857
    150701	25849
    150816	25836
    150922	25813
    151409	25793
    151416	25784
    151424	25781
    151706	25777
    151716	25751
    152001	25699
    152182	25678
    152749	25669
    152899	25649
    153184	25597
    153365	25576
    153932	25567
    154508	25548
    154974	25523
    155155	25502
    155510	25467
    155691	25446
    156275	25438
    156567	25401
    157300	25393
    157387	25366
    157727	25335
    158107	25317
    158597	25303
    158722	25297
    158903	25276
    159487	25268
    159713	25236
    159778	25220
    159959	25199
    160526	25190
    160929	25160
    161569	25157
    161819	25142
    161978	25126
    162104	25090
    162285	25069
    162925	25066
    162980	25045
    163161	25024
    163738	25020
    163960	25011
    164141	24990
    164981	24983
    165011	24958
    165190	24956
    165316	24920
    165497	24899
    166192	24875
    166373	24854
    167353	24850
    167930	24846
    168193	24813
    169069	24768
    169689	24725
    170384	24701
    170565	24680
    172385	24639
    173080	24615
    173261	24594
    177094	24582
    177275	24561
    177713	24559"""
    n = 2124 - 2 + 1
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        coords[i, 0] = int(next(it))
        coords[i, 1] = int(next(it))
    return coords

# %%
def euclidEF100():
    coords_string= """24533	167044
    24544	164353
    24555	162769
    24567	162476
    24578	160892
    24609	160237
    24620	158653
    24657	158438
    24672	157813
    24709	157598
    24729	157258
    24748	157066
    24762	155572
    24791	154871
    24814	154732
    24828	154656
    24843	154031
    24880	153816
    24904	153779
    24907	153613
    24919	153601
    24926	153523
    24933	151790
    24970	151575
    24985	150950
    25022	150735
    25046	150698
    25052	150270
    25075	150131
    25078	149831
    25090	149819
    25104	149430
    25128	149193
    25129	149050
    25130	148991
    25142	148979
    25152	148602
    25156	148259
    25167	147980
    25179	147811
    25194	147189
    25219	147140
    25246	146349
    25307	146097
    25311	145891
    25342	145815
    25351	145662
    25360	145512
    25362	145383
    25374	145214
    25389	144592
    25414	144543
    25441	143752
    25502	143500
    25506	143294
    25537	143218
    25550	143132
    25554	143060
    25555	142915
    25559	142777
    25583	142716
    25589	142378
    25604	142105
    25629	142056
    25654	141920
    25656	141265
    25702	141020
    25717	141013
    25721	140807
    25745	140535
    25749	140463
    25754	140180
    25804	139891
    25819	139722
    25829	139556
    25858	139352
    25868	139343
    25873	139331
    25890	139304
    25893	139161
    25896	139144
    25897	139089
    25902	138806
    25917	138533
    25942	138484
    25955	138331
    25960	138048
    25964	137976
    25969	137693
    26025	137590
    26029	137518
    26030	137441
    26034	137235
    26044	137069
    26073	136865
    26083	136856
    26088	136844
    26090	136824
    26105	136817
    26112	136602
    26117	136319
    26142	135984
    26182	135861
    26192	135695
    26221	135491
    26236	135470
    26238	135450
    26246	135156
    26281	134965
    26284	134948
    26290	134610
    26305	134337
    26348	133852
    26357	133497
    26418	133245
    26452	133024
    26453	132963
    26461	132669
    26496	132478
    26500	132406
    26505	132123
    26566	131871
    26582	131798
    26600	131650
    26604	131578
    26609	131295
    26670	131043
    26682	130873
    26710	130781
    26721	130779
    26725	130707
    26729	130653
    26730	130424
    26754	130235
    26786	130045
    26815	129983
    26816	129978
    26825	129951
    26829	129879
    26834	129596
    26858	129407
    26895	129344
    26907	129174
    26911	129003
    26931	128985
    26954	128954
    26956	128795
    26972	128751
    26979	128536
    27007	128469
    27011	128346
    27015	128175
    27035	128157
    27054	127912
    27059	127629
    27120	127377
    27136	127304
    27156	127286
    27163	126801
    27216	126621
    27224	126549
    27236	126379
    27266	126312
    27279	126213
    27283	126159
    27284	125930
    27328	125877
    27330	125784
    27340	125551
    27370	125484
    27383	125385
    27388	125102
    27434	124956
    27441	124922
    27449	124850
    27461	124680
    27491	124613
    27508	124460
    27510	124301
    27547	124234
    27553	124178
    27555	124085
    27565	123852
    27595	123785
    27614	123473
    27659	123257
    27675	123221
    27685	123210
    27700	123110
    27712	123077
    27717	122984
    27730	122928
    27734	122831
    27741	122698
    27772	122535
    27793	122519
    27794	122515
    27802	122446
    27804	122282
    27814	122276
    27821	122156
    27841	122070
    27850	121965
    27853	121903
    27862	121827
    27898	121687
    27908	121681
    27914	121648
    27918	121448
    27948	121381
    27963	121269
    27966	120999
    28012	120853
    28018	120820
    28019	120819
    28027	120747
    28039	120577
    28067	120441
    28086	120357
    28088	120198
    28125	120131
    28131	120075
    28133	119982
    28143	119749
    28173	119682
    28192	119370
    28237	119154
    28253	119118
    28263	119107
    28278	119007
    28290	118974
    28295	118881
    28306	118871
    28308	118825
    28312	118728
    28327	118628
    28350	118432
    28372	118412
    28382	118179
    28399	118053
    28428	117862
    28431	117800
    28466	117796
    28470	117790
    28476	117584
    28502	117537
    28519	117411
    28529	117404
    28548	117220
    28551	117158
    28562	117132
    28585	117093
    28590	116889
    28624	116858
    28635	116545
    28673	116479
    28678	116466
    28688	116271
    28696	116094
    28749	115914
    28755	115903
    28782	115676
    28808	115629
    28816	115452
    28843	115424
    28853	115347
    28864	115315
    28869	115272
    28895	114954
    28906	114931
    28937	114777
    28945	114657
    28973	114414
    28989	114359
    29015	114312
    29025	114290
    29026	114289
    29034	114162
    29057	114135
    29064	114086
    29065	114015
    29093	113772
    29109	113717
    29138	113490
    29152	113340
    29180	113097
    29219	112893
    29258	112848
    29272	112698
    29300	112455
    29339	112251
    29405	112009
    29431	111962
    29444	111805
    29455	111769
    29470	111758
    29507	111645
    29516	111517
    29525	111367
    29558	111241
    29564	111163
    29575	111127
    29592	111088
    29597	111037
    29620	110845
    29634	110695
    29662	110452
    29712	110446
    29717	110395
    29740	110203
    29754	110053
    29782	109810
    29845	109757
    29871	109710
    29880	109694
    29887	109364
    29913	109317
    29942	109307
    29953	109271
    29964	109132
    29965	109115
    29998	108989
    30007	108722
    30040	108596
    30084	108490
    30118	108347
    30132	108197
    30160	107954
    30223	107901
    30241	107714
    30263	107641
    30265	107508
    30291	107461
    30331	107416
    30340	107409
    30342	107276
    30343	107259
    30385	106866
    30456	106798
    30462	106634
    30497	106633
    30499	106500
    30523	106494
    30525	106481
    30543	106394
    30556	106328
    30566	106295
    30577	106251
    30601	106245
    30619	105858
    30643	105852
    30681	105710
    30686	105653
    30758	105478
    30759	105473
    30783	105467
    30790	105320
    30798	105286
    30801	105180
    30827	105150
    30856	105145
    30857	105115
    30863	105021
    30879	104931
    30884	104822
    30885	104819
    30912	104579
    30921	104538
    30983	104379
    31004	104180
    31032	103937
    31118	103816
    31137	103491
    31163	103444
    31203	103399
    31214	103259
    31250	103179
    31257	102849
    31290	102723
    31334	102617
    31371	102483
    31382	102324
    31410	102081
    31491	101841
    31513	101768
    31515	101635
    31541	101588
    31581	101543
    31590	101536
    31592	101403
    31627	101402
    31635	100993
    31706	100925
    31712	100761
    31747	100760
    31749	100627
    31773	100621
    31775	100608
    31793	100521
    31806	100455
    31816	100422
    31852	100376
    31869	99985
    31893	99979
    31931	99837
    31936	99780
    32008	99605
    32009	99600
    32033	99594
    32040	99447
    32049	99440
    32051	99307
    32102	99299
    32135	99241
    32156	99209
    32162	99068
    32165	98829
    32171	98665
    32276	98567
    32310	98506
    32311	98280
    32342	98127
    32395	98065
    32396	98060
    32420	98054
    32432	97931
    32437	97921
    32467	97509
    32552	97289
    32576	97283
    32638	96971
    32682	96914
    32698	96740
    32734	96611
    32780	96508
    32835	96324
    32854	95969
    32900	95866
    32959	95836
    32978	95758
    33014	95652
    33019	95605
    33025	95431
    33076	95352
    33079	95194
    33131	95168
    33157	95086
    33174	95034
    33180	94991
    33196	94710
    33255	94680
    33278	94585
    33293	94504
    33310	94496
    33315	94449
    33356	94322
    33359	94319
    33361	94130
    33375	94038
    33398	93943
    33427	93941
    33457	93913
    33463	93812
    33477	93785
    33494	93777
    33518	93628
    33538	93558
    33544	93546
    33563	93497
    33574	93429
    33577	93271
    33583	93170
    33642	93140
    33688	93072
    33694	92787
    33743	92782
    33753	92757
    33762	92498
    33858	92312
    33863	92295
    33873	92115
    33922	92110
    33925	92018
    33926	91938
    33961	91889
    33997	91871
    34038	91861
    34042	91593
    34081	91247
    34140	91217
    34186	91149
    34239	91143
    34244	90960
    34256	90927
    34260	90575
    34326	90561
    34365	90477
    34401	90312
    34431	90310
    34435	90255
    34501	90241
    34506	90214
    34517	90152
    34519	90136
    34521	90127
    34550	90047
    34570	89894
    34580	89640
    34641	89574
    34685	89542
    34696	89480
    34746	89476
    34752	89414
    34800	89388
    34801	89382
    34816	89254
    34820	88902
    34886	88888
    34907	88842
    34925	88804
    34932	88750
    34961	88639
    34995	88582
    35048	88447
    35052	88392
    35072	88312
    35135	88287
    35140	87967
    35206	87946
    35243	87939
    35245	87869
    35252	87815
    35256	87807
    35274	87679
    35350	87637
    35357	87502
    35441	87319
    35465	87226
    35467	87169
    35497	87143
    35526	87011
    35613	86840
    35654	86807
    35658	86752
    35678	86672
    35715	86462
    35792	86357
    35853	86213
    35858	86175
    35880	86039
    35917	85829
    35971	85685
    36063	85531
    36103	85503
    36168	85433
    36171	85342
    36219	85200
    36268	85148
    36291	85076
    36301	85074
    36313	85060
    36345	84961
    36352	84684
    36447	84476
    36531	84012
    36636	83914
    36712	83842
    36777	83761
    36781	83739
    36846	83677
    36897	83436
    36925	83398
    36963	83305
    36974	83291
    37004	83199
    37074	83194
    37079	83193
    37103	83104
    37127	83003
    37173	82954
    37181	82856
    37220	82802
    37231	82736
    37244	82706
    37268	82525
    37282	82432
    37384	82222
    37399	82130
    37423	82034
    37547	81912
    37550	81814
    37609	81732
    37666	81469
    37771	81371
    37816	81184
    37921	81086
    37946	80953
    37999	80951
    38027	80891
    38032	80811
    38062	80807
    38080	80793
    38082	80709
    38096	80518
    38160	80477
    38226	80318
    38262	80264
    38355	80259
    38372	80114
    38379	80062
    38393	79969
    38418	79932
    38442	79836
    38472	79775
    38495	79759
    38534	79587
    38558	79491
    38663	79417
    38682	79369
    38684	79302
    38708	79206
    38812	79196
    38824	78995
    38928	78973
    38938	78937
    38952	78877
    38966	78794
    39002	78746
    39013	78592
    39057	78490
    39137	78470
    39150	78203
    39207	78055
    39277	77990
    39317	77983
    39337	77855
    39404	77806
    39425	77712
    39452	77690
    39491	77634
    39499	77488
    39580	77434
    39604	77390
    39620	77260
    39627	77232
    39667	77058
    39688	76910
    39757	76878
    39759	76762
    39806	76560
    39911	76462
    39987	76390
    40011	76314
    40040	76198
    40048	76052
    40087	75996
    40095	75850
    40200	75752
    40276	75680
    40354	75664
    40366	75655
    40367	75606
    40381	75582
    40438	75413
    40471	75215
    40533	75101
    40546	75053
    40625	75006
    40638	75003
    40659	74884
    40702	74778
    40745	74721
    40784	74640
    40805	74616
    40814	74537
    40822	74391
    40877	74251
    40899	74237
    40924	74049
    40963	73968
    41105	73879
    41132	73842
    41144	73798
    41188	73375
    41282	73347
    41301	73325
    41311	73170
    41424	73120
    41449	73085
    41492	73000
    41514	72960
    41561	72758
    41590	72615
    41666	72612
    41674	72594
    41690	72509
    41713	72410
    41767	72355
    41822	72310
    41880	72305
    41894	72240
    41946	72188
    41948	72185
    41955	72144
    41969	72050
    41988	71850
    42035	71648
    42148	71598
    42169	71595
    42203	71531
    42216	71478
    42226	71466
    42246	71331
    42264	71253
    42296	71200
    42318	71170
    42329	71060
    42347	71046
    42365	70968
    42393	70946
    42437	70888
    42489	70846
    42506	70745
    42545	70689
    42553	70543
    42607	70460
    42646	70404
    42654	70258
    42778	70136
    42835	70088
    42866	70032
    42928	70009
    42959	69966
    42984	69930
    42990	69910
    43036	69899
    43047	69862
    43068	69813
    43082	69784
    43109	69717
    43144	69648
    43188	69642
    43196	69496
    43246	69476
    43250	69413
    43289	69357
    43297	69211
    43421	69089
    43478	69041
    43509	68985
    43533	68911
    43547	68899
    43608	68856
    43624	68831
    43638	68724
    43646	68578
    43790	68319
    43903	68269
    43963	68199
    44002	68093
    44051	68029
    44061	67893
    44192	67559
    44274	67440
    44352	67398
    44404	67333
    44433	67272
    44453	67269
    44486	67242
    44494	67096
    44620	67085
    44676	66680
    44835	66512
    44888	66454
    44950	66431
    44981	66420
    45006	66352
    45047	66286
    45080	66183
    45112	66086
    45122	65958
    45211	65849
    45272	65726
    45388	65657
    45416	65642
    45423	65623
    45424	65496
    45473	65452
    45524	65198
    45717	65129
    45736	64972
    45798	64949
    45851	64848
    45864	64784
    45915	64743
    45939	64724
    45947	64578
    46007	64567
    46011	64522
    46067	64449
    46110	64285
    46142	64188
    46233	64097
    46241	63951
    46410	63905
    46414	63831
    46418	63759
    46453	63725
    46503	63658
    46630	63533
    46650	63520
    46669	63477
    46715	63432
    46731	63341
    46808	63323
    46816	63177
    46848	63154
    46896	63041
    47020	62919
    47113	62905
    47144	62848
    47148	62809
    47157	62794
    47170	62792
    47174	62774
    47200	62761
    47217	62747
    47244	62703
    47273	62664
    47280	62606
    47288	62460
    47396	62441
    47455	62351
    47461	62320
    47462	62314
    47475	62295
    47489	62288
    47494	62217
    47507	62198
    47521	62166
    47585	62126
    47588	62097
    47593	61980
    47606	61961
    47620	61954
    47748	61943
    47762	61934
    47766	61860
    47770	61788
    47783	61769
    47797	61762
    47801	61737
    47818	61735
    47832	61728
    47855	61687
    47868	61668
    47882	61661
    47970	61590
    47982	61562
    48009	61536
    48013	61511
    48021	61506
    48034	61487
    48048	61480
    48051	61409
    48083	61370
    48106	61361
    48110	61344
    48191	61269
    48200	61183
    48213	61164
    48216	61111
    48279	61103
    48340	60989
    48369	60949
    48401	60852
    48492	60761
    48500	60615
    48572	60577
    48669	60569
    48673	60495
    48677	60423
    48719	60391
    48762	60322
    48869	60305
    48881	60199
    48901	60194
    48928	60141
    48998	60041
    49000	60015
    49004	60011
    49012	59865
    49107	59818
    49216	59785
    49224	59639
    49286	59616
    49309	59593
    49371	59589
    49375	59540
    49408	59468
    49440	59391
    49498	59390
    49502	59255
    49539	59134
    49630	59130
    49643	59071
    49714	59015
    49776	59006
    49790	58986
    49799	58983
    49812	58947
    49813	58885
    49836	58862
    49917	58822
    49930	58781
    49952	58693
    49967	58660
    50002	58655
    50039	58534
    50083	58359
    50297	58260
    50336	58249
    50357	58110
    50380	58087
    50467	58060
    50491	57975
    50511	57885
    50583	57759
    50649	57706
    50772	57683
    50785	57636
    50808	57613
    50857	57510
    50919	57501
    50923	57457
    50946	57434
    50968	57428
    51011	57285
    51077	57232
    51163	57216
    51200	57209
    51215	57134
    51285	57036
    51340	57025
    51351	56983
    51374	56960
    51454	56914
    51468	56828
    51534	56775
    51591	56742
    51643	56660
    51661	56646
    51684	56551
    51715	56534
    51721	56487
    51836	56478
    51841	56361
    51918	56356
    51945	56298
    51995	56238
    52004	56223
    52012	56194
    52041	56060
    52118	56035
    52149	56013
    52214	56003
    52221	55887
    52251	55882
    52276	55766
    52377	55732
    52385	55586
    52495	55561
    52550	55517
    52573	55494
    52634	55454
    52649	55413
    52659	55337
    52704	55292
    52751	55289
    52790	55276
    52805	55258
    52813	55112
    52899	55096
    52949	55072
    52978	54980
    53052	54928
    53064	54903
    53087	54863
    53095	54815
    53161	54690
    53264	54663
    53270	54655
    53293	54598
    53342	54594
    53356	54566
    53406	54506
    53435	54441
    53492	54429
    53500	54344
    53523	54341
    53589	54216
    53692	54189
    53750	54141
    53764	54063
    53830	54010
    53863	53967
    53928	53870
    53939	53830
    54038	53814
    54046	53759
    54103	53731
    54154	53724
    54174	53713
    54192	53589
    54213	53581
    54239	53577
    54258	53536
    54320	53510
    54359	53502
    54367	53356
    54446	53315
    54509	53283
    54531	53257
    54552	53200
    54618	53147
    54641	53107
    54715	53079
    54720	53066
    54777	53054
    54782	53048
    54783	53034
    54805	53008
    54813	52960
    54822	52913
    54824	52899
    54879	52835
    54952	52761
    54980	52726
    55046	52673
    55096	52664
    55098	52650
    55153	52586
    55201	52574
    55226	52512
    55250	52439
    55307	52361
    55423	52355
    55437	52269
    55503	52216
    55524	52190
    55581	52112
    55640	52042
    55707	51982
    55764	51904
    55833	51876
    55886	51872
    55941	51868
    55945	51802
    55956	51764
    55981	51733
    56038	51655
    56107	51627
    56124	51606
    56146	51488
    56238	51451
    56308	51424
    56310	51389
    56398	51357
    56411	51295
    56451	51248
    56512	51202
    56541	51197
    56581	51149
    56638	51140
    56650	51121
    56685	51100
    56687	51058
    56741	51011
    56773	51000
    56798	50978
    56815	50948
    56830	50922
    56839	50875
    56868	50838
    56896	50797
    56947	50787
    56963	50733
    57041	50718
    57055	50696
    57104	50673
    57113	50626
    57169	50591
    57170	50548
    57226	50513
    57229	50478
    57287	50465
    57296	50418
    57353	50340
    57422	50312
    57500	50264
    57545	50200
    57559	50194
    57570	50169
    57626	50134
    57627	50091
    57683	50056
    57713	50042
    57735	49924
    57827	49887
    57899	49825
    57957	49807
    57987	49793
    58002	49743
    58046	49723
    58065	49640
    58101	49638
    58157	49603
    58170	49585
    58229	49541
    58276	49494
    58332	49459
    58362	49445
    58376	49439
    58387	49414
    58431	49354
    58444	49336
    58500	49301
    58552	49169
    58644	49132
    58716	49070
    58774	49052
    58819	48988
    58882	48885
    58918	48883
    58974	48848
    59046	48786
    59093	48739
    59149	48704
    59248	48599
    59357	48580
    59423	48455
    59615	48420
    59671	48385
    59749	48345
    59780	48324
    59798	48212
    59945	48136
    59998	48127
    60012	48121
    60023	48096
    60072	47963
    60128	47928
    60188	47851
    60280	47814
    60352	47752
    60402	47679
    60455	47670
    60518	47567
    60554	47565
    60610	47530
    60682	47468
    60729	47421
    60785	47386
    60884	47281
    60993	47262
    61059	47137
    61312	47111
    61405	47076
    61430	47045
    61466	47028
    61469	47023
    61476	46983
    61487	46967
    61532	46903
    61679	46827
    61740	46779
    61796	46744
    61806	46654
    61862	46619
    62035	46580
    62070	46495
    62136	46370
    62299	46361
    62447	46263
    62496	46221
    62504	46185
    62581	46176
    62638	46145
    62655	46122
    62745	46077
    62777	45979
    62782	45949
    62834	45901
    62960	45892
    62968	45861
    63092	45806
    63112	45665
    63332	45653
    63386	45626
    63422	45522
    63637	45441
    63751	45425
    63759	45402
    63771	45397
    63856	45308
    63868	45303
    63901	45251
    63967	45157
    63983	45135
    63995	45130
    64078	45089
    64090	45084
    64226	45045
    64231	44967
    64313	44851
    64325	44846
    64408	44805
    64420	44800
    64683	44588
    64695	44583
    64968	44545
    65052	44544
    65102	44437
    65114	44432
    65278	44421
    65290	44416
    65298	44261
    65432	44153
    65444	44148
    65720	44130
    65732	44125
    65815	44084
    65827	44079
    65925	44042
    65933	43896
    65945	43891
    66090	43867
    66102	43862
    66310	43800
    66312	43791
    66324	43786
    66456	43761
    66498	43698
    66510	43693
    66538	43615
    66550	43610
    66705	43540
    66791	43505
    66803	43500
    66839	43432
    66851	43427
    66995	43407
    67007	43402
    67016	43398
    67059	43365
    67061	43356
    67073	43351
    67123	43347
    67205	43306
    67212	43268
    67213	43248
    67222	43234
    67234	43229
    67339	43226
    67340	43175
    67352	43170
    67386	43135
    67398	43130
    67560	43108
    67562	43099
    67574	43094
    67575	43063
    67657	42947
    67669	42942
    67752	42901
    67764	42896
    67945	42894
    67957	42889
    67961	42833
    67962	42813
    67971	42799
    67983	42794
    68027	42684
    68039	42679
    68224	42653
    68236	42648
    68312	42641
    68319	42607
    68331	42602
    68367	42574
    68379	42569
    68446	42533
    68458	42528
    68542	42430
    68554	42425
    68594	42390
    68606	42385
    68642	42357
    68740	42321
    68752	42316
    68776	42249
    68788	42244
    69004	42162
    69016	42157
    69067	42145
    69070	42037
    69082	42032
    69277	41992
    69289	41987
    69343	41955
    69355	41950
    69480	41946
    69492	41941
    69616	41905
    69654	41896
    69656	41887
    69668	41882
    69682	41818
    69816	41710
    69828	41705
    69844	41698
    69856	41693
    70001	41669
    70013	41664
    70049	41636
    70183	41528
    70195	41523
    70229	41511
    70241	41506
    70317	41453
    70329	41448
    70417	41447
    70528	41396
    70540	41391
    70616	41342
    70684	41271
    70696	41266
    70730	41254
    70742	41249
    70750	41234
    70762	41229
    70904	41204
    70906	41195
    70918	41190
    70970	41167
    70972	41158
    70984	41153
    71133	41077
    71143	41069
    71251	40977
    71263	40972
    71277	40961
    71289	40956
    71471	40910
    71473	40901
    71485	40896
    71611	40866
    71745	40858
    71770	40850
    71778	40704
    71790	40699
    72055	40687
    72067	40682
    72083	40614
    72095	40609
    72124	40604
    72167	40603
    72170	40602
    72253	40591
    72265	40586
    72266	40531
    72278	40526
    72363	40505
    72375	40500
    72436	40468
    72448	40463
    72480	40405
    72610	40377
    72614	40297
    72626	40292
    72770	40281
    72864	40248
    72876	40243
    72881	40204
    72904	40173
    72916	40168
    73015	40096
    73027	40091
    73115	40040
    73127	40035
    73311	40031
    73358	39996
    73359	39942
    73371	39937
    73405	39916
    73417	39911
    73492	39888
    73504	39883
    73516	39839
    73528	39834
    73785	39802
    73797	39797
    73800	39779
    73812	39774
    73860	39685
    73872	39680
    73993	39631
    74005	39626
    74149	39584
    74161	39579
    74424	39455
    74436	39450
    74732	39436
    74744	39431
    74879	39401
    74891	39396
    74932	39383
    74944	39378
    74983	39307
    74995	39302
    75076	39282
    75088	39277
    75209	39228
    75221	39223
    75356	39193
    75365	39181
    75377	39176
    75406	39160
    75418	39155
    75496	39153
    75508	39148
    75512	39146
    75524	39141
    75539	39106
    75551	39101
    75640	39052
    75652	39047
    75787	39017
    75799	39012
    75886	39008
    75925	39003
    75970	38930
    75982	38925
    76118	38915
    76130	38910
    76143	38908
    76164	38889
    76176	38884
    76251	38861
    76263	38856
    76275	38812
    76287	38807
    76403	38791
    76415	38786
    76475	38759
    76487	38754
    76559	38752
    76571	38747
    76608	38705
    76619	38658
    76631	38653
    76752	38604
    76764	38599
    76908	38557
    76920	38552
    77039	38529
    77051	38524
    77183	38428
    77195	38423
    77598	38381
    77610	38376
    77638	38374
    77650	38369
    77742	38280
    77754	38275
    77971	38267
    77982	38220
    77994	38215
    78115	38166
    78127	38161
    78253	38152
    78265	38147
    78271	38119
    78283	38114
    78386	38098
    78398	38093
    78402	38091
    78414	38086
    78542	38051
    78546	37990
    78558	37985
    78817	37922
    78829	37917
    78888	37912
    78960	37906
    78972	37901
    78975	37884
    78987	37879
    79105	37842
    79117	37837
    79212	37824
    79224	37819
    79293	37799
    79304	37752
    79316	37747
    79437	37698
    79449	37693
    79593	37651
    79605	37646
    79724	37623
    79736	37618
    79868	37522
    79880	37517
    80259	37469
    80271	37464
    80335	37463
    80338	37446
    80350	37441
    80427	37374
    80439	37369
    80656	37361
    80667	37314
    80679	37309
    80743	37298
    80755	37293
    80800	37260
    80812	37255
    80935	37227
    80947	37222
    80956	37213
    80968	37208
    81071	37192
    81083	37187
    81087	37185
    81099	37180
    81227	37145
    81231	37084
    81243	37079
    81478	37033
    81479	37029
    81490	37028
    81491	37024
    81502	37016
    81514	37011
    81573	37006
    81584	36990
    81596	36985
    81660	36978
    81672	36973
    81790	36936
    81802	36931
    81827	36898
    81839	36893
    81902	36887
    81914	36882
    81967	36846
    81971	36797
    81983	36792
    82195	36761
    82207	36756
    82321	36752
    82331	36720
    82343	36715
    82551	36650
    82563	36645
    82722	36643
    82824	36638
    82836	36633
    82841	36595
    82842	36591
    82853	36590
    82854	36586
    82944	36563
    82956	36558
    82959	36547
    82961	36535
    82973	36530
    83087	36526
    83099	36521
    83105	36434
    83117	36429
    83231	36425
    83243	36420
    83334	36359
    83346	36354
    83477	36352
    83591	36348
    83603	36343
    83605	36291
    83617	36286
    83694	36282
    83706	36277
    83754	36197
    83766	36192
    83880	36188
    83892	36183
    84114	36120
    84126	36115
    84240	36111
    84252	36106
    84281	36079
    84455	36077
    84488	36072
    84493	36026
    84512	35992
    84524	35987
    84587	35981
    84599	35976
    84652	35940
    84656	35891
    84668	35886
    84880	35855
    84892	35850
    85006	35846
    85016	35814
    85028	35809
    85236	35744
    85248	35739
    85333	35734
    85526	35689
    85538	35684
    85554	35680
    85626	35679
    85646	35629
    85658	35624
    85704	35595
    85716	35590
    85790	35528
    85802	35523
    85916	35519
    85928	35514
    86019	35453
    86031	35448
    86162	35446
    86276	35442
    86288	35399
    86290	35385
    86302	35380
    86379	35376
    86391	35371
    86439	35291
    86451	35286
    86565	35282
    86577	35277
    86799	35214
    86811	35209
    86925	35205
    86937	35200
    87015	35198
    87036	35197
    87110	35184
    87122	35179
    87188	35174
    87224	35121
    87236	35116
    87306	35103
    87318	35098
    87347	35047
    87359	35042
    87473	35038
    87485	35033
    87491	34946
    87503	34941
    87617	34937
    87629	34932
    87851	34869
    87863	34864
    87977	34860
    87989	34855
    88088	34852
    88213	34848
    88242	34846
    88243	34788
    88328	34783
    88345	34780
    88358	34758
    88370	34753
    88484	34749
    88496	34744
    88514	34720
    88587	34683
    88599	34678
    88753	34636
    88765	34631
    88870	34610
    88897	34535
    88909	34530
    89023	34526
    89035	34521
    89066	34518
    89180	34514
    89192	34509
    89257	34458
    89269	34453
    89283	34448
    89295	34443
    89439	34419
    89451	34414
    89554	34380
    89566	34375
    89722	34346
    89776	34342
    89890	34338
    89902	34333
    89981	34332
    89993	34272
    90005	34267
    90151	34207
    90163	34202
    90279	34193
    90370	34136
    90382	34131
    90400	34128
    90419	34110
    90431	34105
    90545	34101
    90557	34096
    90651	34094
    90689	34037
    90701	34032
    90791	34028
    90845	34008
    90857	34003
    90882	33994
    90972	33964
    91171	33952
    91256	33947
    91259	33939
    91286	33922
    91298	33917
    91399	33909
    91411	33904
    91425	33892
    91435	33872
    91515	33847
    91527	33842
    91557	33796
    91569	33791
    91685	33782
    91726	33779
    91776	33725
    91788	33720
    91806	33717
    91825	33699
    91837	33694
    91951	33690
    91963	33685
    91994	33682
    92091	33641
    92103	33636
    92185	33622
    92197	33617
    92211	33612
    92223	33607
    92288	33583
    92379	33578
    92451	33564
    92463	33559
    92475	33532
    92487	33527
    92613	33518
    92692	33511
    92704	33506
    92758	33503
    92818	33502
    92830	33497
    92843	33483
    92847	33450
    92921	33436
    92933	33431
    93030	33397
    93042	33392
    93060	33389
    93132	33368
    93204	33363
    93207	33357
    93298	33300
    93310	33295
    93328	33292
    93388	33276
    93400	33271
    93497	33230
    93509	33225
    93617	33201
    93629	33196
    93773	33172
    93785	33167
    93798	33163
    93810	33158
    93857	33153
    93869	33148
    93881	33121
    93893	33116
    94019	33107
    94154	33098
    94166	33070
    94253	33039
    94267	33034
    94279	33029
    94403	33022
    94415	32966
    94427	32961
    94541	32957
    94553	32952
    94613	32946
    94704	32889
    94716	32884
    94734	32881
    94830	32880
    94842	32875
    94948	32844
    94970	32831
    94982	32826
    95000	32823
    95060	32807
    95072	32802
    95186	32798
    95198	32793
    95204	32752
    95216	32747
    95289	32732
    95301	32727
    95366	32717
    95384	32714
    95445	32703
    95457	32698
    95470	32694
    95482	32689
    95560	32664
    95572	32659
    95673	32623
    95685	32618
    95809	32611
    95821	32555
    95833	32550
    95947	32546
    95959	32541
    95990	32538
    96104	32534
    96116	32529
    96181	32478
    96193	32473
    96207	32468
    96219	32463
    96363	32439
    96375	32434
    96376	32420
    96388	32415
    96406	32412
    96490	32395
    96634	32371
    96646	32366
    96700	32362
    96754	32359
    96760	32311
    96772	32306
    96790	32303
    96876	32283
    96888	32278
    97041	32269
    97122	32268
    97150	32257
    97162	32252
    97180	32249
    97203	32213
    97244	32209
    97260	32174
    97272	32169
    97294	32156
    97306	32151
    97324	32148
    97384	32132
    97396	32127
    97510	32123
    97522	32118
    97575	32114
    97613	32057
    97625	32052
    97769	32028
    97781	32023
    97794	32019
    97806	32014
    97884	31989
    97896	31984
    98052	31955
    98229	31954
    98233	31948
    98245	31943
    98292	31917
    98304	31912
    98465	31903
    98500	31886
    98556	31846
    98568	31841
    98586	31838
    98597	31807
    98609	31802
    98688	31801
    98700	31745
    98712	31740
    98730	31737
    98826	31736
    98838	31731
    98969	31708
    98981	31703
    99062	31702
    99095	31699
    99107	31694
    99157	31691
    99180	31687
    99188	31664
    99200	31608
    99212	31603
    99434	31598
    99446	31593
    99585	31581
    99602	31564
    99623	31548
    99635	31543
    99713	31538
    99772	31526
    99858	31506
    99870	31501
    99894	31480
    99906	31475
    99980	31438
    100111	31404
    100123	31399
    100141	31396
    100237	31395
    100249	31390
    100294	31376
    100306	31371
    100380	31367
    100392	31362
    100473	31360
    100506	31358
    100518	31353
    100552	31318
    100595	31284
    100607	31279
    100611	31267
    100623	31262
    100776	31242
    100788	31237
    100866	31235
    100878	31230
    100967	31221
    100979	31175
    100991	31170
    101227	31166
    101242	31128
    101369	31121
    101374	31032
    101386	31027
    101513	31020
    101525	31015
    101530	31003
    101542	30998
    101700	30965
    101712	30960
    101952	30949
    101964	30944
    101969	30928
    101981	30923
    102050	30904
    102062	30899
    102170	30887
    102182	30831
    102194	30826
    102451	30794
    102463	30789
    102610	30786
    102622	30781
    102683	30766
    102695	30761
    102775	30710
    102785	30691
    102797	30686
    102907	30665
    102919	30609
    102931	30604
    103188	30572
    103200	30567
    103384	30523
    103396	30518
    103593	30490
    103605	30485
    103607	30483
    103619	30478
    103744	30446
    103756	30441
    103981	30422
    103992	30396
    104004	30391
    104186	30369
    104198	30364
    104293	30359
    104318	30324
    104330	30268
    104342	30263
    104599	30231
    104611	30226
    104795	30182
    104807	30177
    104974	30174
    105018	30142
    105030	30137
    105155	30105
    105167	30100
    105375	30067
    105387	30011
    105399	30006
    105687	29985
    105699	29980
    105819	29940
    105831	29884
    105843	29879
    106287	29878
    106295	29870
    106307	29865
    106326	29817
    106338	29812
    106595	29780
    106607	29775
    106654	29771
    106666	29766
    106686	29740
    106698	29735
    106786	29726
    106798	29670
    106810	29665
    107098	29644
    107110	29639
    107227	29609
    107230	29599
    107242	29543
    107254	29538
    107598	29532
    107610	29527
    107737	29476
    107749	29471
    107950	29466
    108006	29439
    108018	29434
    108048	29415
    108060	29410
    108097	29399
    108109	29394
    108317	29378
    108329	29373
    108366	29362
    108378	29357
    108382	29344
    108394	29339
    108467	29330
    108479	29325
    108608	29324
    108693	29319
    108694	29313
    108706	29308
    108728	29284
    108740	29228
    108752	29223
    109009	29191
    109021	29186
    109241	29163
    109253	29158
    109428	29102
    109440	29097
    109459	29074
    109471	29069
    109673	29068
    109685	29063
    109709	29060
    109728	29037
    109740	29032
    109880	29029
    109892	29024
    109960	29009
    109972	29004
    110147	28948
    110159	28943
    110183	28927
    110195	28922
    110302	28920
    110416	28911
    110428	28906
    110452	28890
    110464	28885
    110571	28883
    110599	28875
    110611	28870
    110684	28862
    110696	28857
    110803	28855
    110868	28838
    110871	28801
    110883	28796
    111105	28795
    111140	28764
    111152	28759
    111219	28738
    111231	28733
    111323	28728
    111335	28723
    111358	28708
    111370	28703
    111488	28701
    111500	28696
    111592	28691
    111604	28686
    111627	28671
    111639	28666
    111824	28663
    111836	28658
    111859	28643
    111871	28638
    111989	28636
    112001	28631
    112011	28602
    112023	28597
    112082	28561
    112094	28556
    112351	28524
    112363	28519
    112498	28509
    112510	28504
    112583	28496
    112595	28491
    112767	28472
    112779	28467
    112852	28459
    112864	28454
    112930	28453
    112999	28444
    113011	28439
    113129	28437
    113141	28432
    113187	28421
    113199	28416
    113222	28362
    113234	28357
    113491	28325
    113503	28320
    113723	28297
    113735	28292
    113992	28260
    114004	28255
    114070	28254
    114327	28222
    114339	28217
    114549	28209
    114559	28194
    114571	28189
    114795	28187
    114818	28172
    114828	28157
    114840	28152
    115050	28144
    115062	28139
    115090	28128
    115102	28123
    115202	28103
    115214	28098
    115273	28062
    115285	28057
    115542	28025
    115554	28020
    115689	28010
    115701	28005
    115774	27997
    115786	27992
    115958	27973
    115970	27968
    116043	27960
    116055	27955
    116121	27954
    116190	27945
    116202	27940
    116320	27938
    116332	27933
    116378	27922
    116390	27917
    116413	27863
    116425	27858
    116682	27826
    116694	27821
    116914	27798
    116926	27793
    117183	27761
    117195	27756
    117238	27716
    117250	27711
    117507	27679
    117519	27674
    117751	27646
    118020	27609
    118086	27608
    118355	27571
    118378	27517
    118390	27512
    118647	27480
    118659	27475
    118879	27452
    118891	27447
    119148	27415
    119160	27410
    119226	27409
    119495	27372
    119727	27344
    119984	27312
    119996	27307
    120421	27285
    120433	27280
    120523	27253
    120535	27248
    120702	27243
    120792	27216
    120804	27211
    121024	27188
    121036	27183
    121203	27178
    121269	27177
    121292	27169
    121293	27151
    121305	27146
    121371	27145
    121538	27140
    121561	27132
    121573	27127
    121640	27108
    121805	27099
    121872	27080
    122039	27075
    122062	27067
    122074	27062
    122129	27048
    122141	27043
    122406	27037
    122409	27024
    122641	26996
    122898	26964
    122910	26959
    123319	26954
    123651	26945
    123772	26929
    123829	26928
    123879	26912
    123896	26909
    124029	26897
    124041	26892
    124065	26889
    124148	26875
    124386	26872
    124398	26867
    124406	26863
    124459	26849
    124483	26837
    124665	26825
    124715	26809
    124929	26801
    124942	26796
    124960	26784
    124984	26772
    125242	26760
    125277	26758
    125295	26746
    125371	26735
    125509	26730
    125511	26723
    125527	26718
    125599	26714
    125694	26713
    125706	26697
    125778	26693
    125796	26681
    125938	26669
    126193	26666
    126207	26632
    126577	26607
    126961	26599
    126974	26592
    127266	26589
    127326	26570
    127338	26565
    127362	26562
    127466	26558
    127551	26547
    127661	26532
    127825	26524
    127887	26518
    127893	26504
    127962	26498
    128162	26467
    128440	26466
    128559	26452
    128637	26433
    129034	26418
    129293	26400
    129317	26397
    129341	26393
    129580	26390
    129610	26356
    129984	26341
    130053	26335
    130195	26332
    130253	26304
    130392	26299
    130650	26289
    130728	26270
    131125	26255
    131384	26237
    131408	26234
    131432	26230
    131547	26229
    131701	26193
    132098	26178
    132214	26173
    132483	26136
    132856	26123
    132880	26121
    133153	26117
    133253	26108
    133460	26104
    133638	26066
    133935	26060
    133973	26058
    134009	26046
    134406	26031
    134522	26026
    134594	26022
    134791	25989
    135128	25988
    135164	25976
    135188	25974
    135461	25970
    135561	25961
    135946	25919
    136243	25913
    136281	25911
    136343	25904
    136678	25896
    137285	25884
    137436	25841
    137733	25835
    137833	25826
    138418	25822
    138860	25814
    138979	25800
    139176	25767
    139473	25761
    139573	25752
    140015	25744
    140412	25729
    140997	25725
    141558	25703
    141755	25670
    142152	25655
    142449	25649
    142993	25648
    143823	25622
    144120	25616
    145066	25615
    145397	25605
    145420	25596
    145794	25590
    146044	25586
    146338	25578
    146552	25535
    146949	25520
    147246	25514
    147790	25513
    148087	25507
    148520	25496
    148620	25487
    148917	25481
    149461	25480
    149697	25476
    149758	25474
    150538	25469
    152409	25450
    152706	25444
    153250	25443
    153486	25439
    153547	25437
    154327	25432"""
    n = 2388 - 2 + 1
    coords = np.zeros((n, 2))
    it = iter(coords_string.split())
    for i in range(n):
        coords[i, 0] = int(next(it))
        coords[i, 1] = int(next(it))
    return coords

# %% [markdown]
# # euclidAB100

# %%
euclidAB100opt = euclidAB100()
plt.scatter(euclidAB100opt[:, 0], euclidAB100opt[:, 1], s=0.1)
plt.figure(figsize=(20, 20))

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidA100()[0]
        self.distMatrixB = euclidB100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv"),
                   crossover=get_crossover("perm_ox"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       4 |            - |            -
#     2 |    2000 |       6 |  0.169886768 |        ideal
#     3 |    3000 |      10 |  0.087793133 |        ideal
#     4 |    4000 |      11 |  0.107121965 |        ideal
#     5 |    5000 |      14 |  0.090494553 |        ideal
#     6 |    6000 |      14 |  0.088585357 |        ideal
#     7 |    7000 |      18 |  0.112945189 |        ideal
#     8 |    8000 |      10 |  0.034189495 |        ideal
#     9 |    9000 |      14 |  0.031994716 |        ideal
#    10 |   10000 |      12 |  0.051949051 |        ideal
#    11 |   11000 |       9 |  0.029115984 |        ideal
#    12 |   12000 |      13 |  0.083368441 |        ideal
#    13 |   13000 |      16 |  0.030949140 |        ideal
#    14 |   14000 |      19 |  0.074066305 |        ideal
#    15 |   15000 |      22 |  0.031264331 |        ideal
#    16 |   16000 |      22 |  0.025384484 |            f
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidA100()[0]
        self.distMatrixB = euclidB100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv"),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       4 |            - |            -
#     2 |    2000 |       8 |  0.122323552 |        ideal
#     3 |    3000 |       7 |  0.265441509 |        ideal
#     4 |    4000 |      13 |  0.195821034 |        ideal
#     5 |    5000 |       8 |  0.089182741 |        ideal
#     6 |    6000 |       9 |  0.178800682 |        ideal
#     7 |    7000 |      15 |  0.132182501 |        ideal
#     8 |    8000 |      13 |  0.148342580 |        ideal
#     9 |    9000 |       8 |  0.093056419 |            f
#    10 |   10000 |       8 |  0.035396120 |        ideal
#    11 |   11000 |       9 |  0.175988361 |        ideal
#    12 |   12000 |      12 |  0.015503696 |        ideal
#    13 |   13000 |      19 |  0.041016488 |            f
#    14 |   14000 |      14 |  0.182574944 |        ideal
#    15 |   15000 |      12 |  0.156694445 |        ideal
#    16 |   16000 |      12 |  0.063379164 |            f
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidA100()[0]
        self.distMatrixB = euclidB100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv"),
                   crossover=get_crossover("perm_ox"))

res = minimize(problem,
               algorithm,
               ("n_gen", 10000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       4 |            - |            -
#     2 |    2000 |       6 |  0.169886768 |        ideal
#     3 |    3000 |      10 |  0.087793133 |        ideal
#     4 |    4000 |      11 |  0.107121965 |        ideal
#     5 |    5000 |      14 |  0.090494553 |        ideal
#     6 |    6000 |      14 |  0.088585357 |        ideal
#     7 |    7000 |      18 |  0.112945189 |        ideal
#     8 |    8000 |      10 |  0.034189495 |        ideal
#     9 |    9000 |      14 |  0.031994716 |        ideal
#    10 |   10000 |      12 |  0.051949051 |        ideal
#    11 |   11000 |       9 |  0.029115984 |        ideal
#    12 |   12000 |      13 |  0.083368441 |        ideal
#    13 |   13000 |      16 |  0.030949140 |        ideal
#    14 |   14000 |      19 |  0.074066305 |        ideal
#    15 |   15000 |      22 |  0.031264331 |        ideal
#    16 |   16000 |      22 |  0.025384484 |            f
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidA100()[0]
        self.distMatrixB = euclidB100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv", prob=0.3),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       4 |            - |            -
#     2 |    2000 |       4 |  0.130838651 |        ideal
#     3 |    3000 |       7 |  0.129290724 |        ideal
#     4 |    4000 |      15 |  0.140179505 |        ideal
#     5 |    5000 |      12 |  0.335180786 |        ideal
#     6 |    6000 |      12 |  0.091218134 |        ideal
#     7 |    7000 |      15 |  0.131029514 |        ideal
#     8 |    8000 |      10 |  0.233278103 |        ideal
#     9 |    9000 |      13 |  0.034088795 |        ideal
#    10 |   10000 |      17 |  0.195877139 |        ideal
#    11 |   11000 |      15 |  0.098269100 |        ideal
#    12 |   12000 |      18 |  0.034045535 |            f
#    13 |   13000 |      12 |  0.115030295 |        ideal
#    14 |   14000 |      14 |  0.121016408 |        ideal
#    15 |   15000 |      18 |  0.113579771 |        nadir
#    16 |   16000 |      15 |  0.114765550 |        ideal
# ...

# %% [markdown]
# # euclidCD100

# %%
euclidCD100opt = euclidCD100()
plt.scatter(euclidCD100opt[:, 0], euclidCD100opt[:, 1], s=0.1)
plt.figure(figsize=(20, 20))

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidC100()[0]
        self.distMatrixB = euclidD100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv"),
                   crossover=get_crossover("perm_ox"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       7 |            - |            -
#     2 |    2000 |       9 |  0.100911537 |        ideal
#     3 |    3000 |       9 |  0.534174807 |        ideal
#     4 |    4000 |      11 |  0.122258830 |        ideal
#     5 |    5000 |      15 |  0.024405887 |        ideal
#     6 |    6000 |      10 |  0.163676503 |        ideal
#     7 |    7000 |      13 |  0.206930912 |        ideal
#     8 |    8000 |      13 |  0.161778475 |        ideal
#     9 |    9000 |      11 |  0.039457948 |            f
#    10 |   10000 |      14 |  0.013944976 |            f
#    11 |   11000 |      14 |  0.025681663 |        ideal
#    12 |   12000 |      25 |  0.041636240 |        ideal
#    13 |   13000 |      26 |  0.051743362 |        ideal
#    14 |   14000 |      13 |  0.047294962 |            f
#    15 |   15000 |       9 |  0.088168052 |        ideal
#    16 |   16000 |      15 |  0.009270850 |        ideal
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidC100()[0]
        self.distMatrixB = euclidD100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv"),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       7 |            - |            -
#     2 |    2000 |      10 |  0.157256305 |        ideal
#     3 |    3000 |      13 |  0.181050628 |        ideal
#     4 |    4000 |      15 |  0.091184095 |        ideal
#     5 |    5000 |      18 |  0.145950158 |        ideal
#     6 |    6000 |      12 |  0.114352237 |        ideal
#     7 |    7000 |      12 |  0.072308718 |        ideal
#     8 |    8000 |      10 |  0.181366325 |        ideal
#     9 |    9000 |      11 |  0.066461075 |        ideal
#    10 |   10000 |      15 |  0.050284170 |        ideal
#    11 |   11000 |      12 |  0.054649311 |        ideal
#    12 |   12000 |      14 |  0.103772028 |        ideal
#    13 |   13000 |      15 |  0.039179794 |        ideal
#    14 |   14000 |      13 |  0.097074943 |        ideal
#    15 |   15000 |      13 |  0.033743552 |        ideal
#    16 |   16000 |      17 |  0.050089032 |        ideal
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidC100()[0]
        self.distMatrixB = euclidD100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv", prob=0.3),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       7 |            - |            -
#     2 |    2000 |       5 |  0.249906085 |        ideal
#     3 |    3000 |       9 |  0.274291316 |        ideal
#     4 |    4000 |      13 |  0.258526036 |        ideal
#     5 |    5000 |      13 |  0.070239477 |        ideal
#     6 |    6000 |      14 |  0.096638177 |        ideal
#     7 |    7000 |      10 |  0.195565202 |        ideal
#     8 |    8000 |      14 |  0.174836555 |        ideal
#     9 |    9000 |      11 |  0.051034795 |        ideal
#    10 |   10000 |      16 |  0.185584743 |        ideal
#    11 |   11000 |      25 |  0.053136699 |            f
#    12 |   12000 |      17 |  0.025234808 |        ideal
#    13 |   13000 |      16 |  0.051052018 |        ideal
#    14 |   14000 |      11 |  0.029532353 |        ideal
#    15 |   15000 |      16 |  0.134195467 |        ideal
#    16 |   16000 |      20 |  0.093955517 |        ideal
# ...

# %% [markdown]
# # euclidEF100

# %%
euclidEF100opt = euclidEF100()
plt.scatter(euclidEF100opt[:, 0], euclidEF100opt[:, 1], s=0.1)
plt.figure(figsize=(20, 20))

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidE100()[0]
        self.distMatrixB = euclidF100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv"),
                   crossover=get_crossover("perm_ox"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       6 |            - |            -
#     2 |    2000 |       9 |  0.331619505 |        ideal
#     3 |    3000 |      13 |  0.045327260 |        ideal
#     4 |    4000 |      15 |  0.104144016 |        ideal
#     5 |    5000 |       9 |  0.106305662 |        ideal
#     6 |    6000 |      12 |  0.253399810 |        ideal
#     7 |    7000 |      15 |  0.095941929 |        ideal
#     8 |    8000 |      13 |  0.029057839 |            f
#     9 |    9000 |      13 |  0.056801299 |            f
#    10 |   10000 |      15 |  0.040139243 |            f
#    11 |   11000 |      12 |  0.014828967 |        ideal
#    12 |   12000 |      13 |  0.051925774 |        ideal
#    13 |   13000 |      14 |  0.032545820 |        ideal
#    14 |   14000 |      15 |  0.075635981 |        ideal
#    15 |   15000 |      15 |  0.006819235 |        ideal
#    16 |   16000 |      22 |  0.042763795 |        ideal
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidE100()[0]
        self.distMatrixB = euclidF100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv"),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       6 |            - |            -
#     2 |    2000 |       7 |  0.246719679 |        ideal
#     3 |    3000 |      10 |  0.067199933 |        ideal
#     4 |    4000 |      15 |  0.103315426 |        ideal
#     5 |    5000 |       9 |  0.276139960 |        ideal
#     6 |    6000 |      16 |  0.201339083 |        ideal
#     7 |    7000 |      14 |  0.053315904 |        ideal
#     8 |    8000 |      12 |  0.058443453 |        ideal
#     9 |    9000 |       9 |  0.294041502 |        ideal
#    10 |   10000 |      10 |  0.092928475 |        ideal
#    11 |   11000 |      11 |  0.081253563 |        ideal
#    12 |   12000 |      15 |  0.048312901 |            f
#    13 |   13000 |      12 |  0.224544447 |        ideal
#    14 |   14000 |      20 |  0.155188252 |        ideal
#    15 |   15000 |      14 |  0.042472264 |            f
#    16 |   16000 |      16 |  0.022714911 |        ideal
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidE100()[0]
        self.distMatrixB = euclidF100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv", prob=0.5),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       6 |            - |            -
#     2 |    2000 |       6 |  0.278209641 |        ideal
#     3 |    3000 |      11 |  0.027303251 |        ideal
#     4 |    4000 |      12 |  0.229035882 |        ideal
#     5 |    5000 |      11 |  0.123683068 |        ideal
#     6 |    6000 |       7 |  0.235145437 |        ideal
#     7 |    7000 |       7 |  0.247693797 |        ideal
#     8 |    8000 |      15 |  0.086188777 |        ideal
#     9 |    9000 |      11 |  0.016199643 |        ideal
#    10 |   10000 |      14 |  0.182801444 |        ideal
#    11 |   11000 |      15 |  0.056941086 |            f
#    12 |   12000 |      19 |  0.014674535 |        ideal
#    13 |   13000 |       7 |  0.130965928 |        ideal
#    14 |   14000 |      10 |  0.184635235 |        ideal
#    15 |   15000 |      15 |  0.156116554 |        ideal
#    16 |   16000 |      12 |  0.029691092 |        ideal
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidE100()[0]
        self.distMatrixB = euclidF100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv", prob=1.0),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       6 |            - |            -
#     2 |    2000 |       7 |  0.246719679 |        ideal
#     3 |    3000 |      10 |  0.067199933 |        ideal
#     4 |    4000 |      15 |  0.103315426 |        ideal
#     5 |    5000 |       9 |  0.276139960 |        ideal
#     6 |    6000 |      16 |  0.201339083 |        ideal
#     7 |    7000 |      14 |  0.053315904 |        ideal
#     8 |    8000 |      12 |  0.058443453 |        ideal
#     9 |    9000 |       9 |  0.294041502 |        ideal
#    10 |   10000 |      10 |  0.092928475 |        ideal
#    11 |   11000 |      11 |  0.081253563 |        ideal
#    12 |   12000 |      15 |  0.048312901 |            f
#    13 |   13000 |      12 |  0.224544447 |        ideal
#    14 |   14000 |      20 |  0.155188252 |        ideal
#    15 |   15000 |      14 |  0.042472264 |            f
#    16 |   16000 |      16 |  0.022714911 |        ideal
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidE100()[0]
        self.distMatrixB = euclidF100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv", prob=0.3),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       6 |            - |            -
#     2 |    2000 |       8 |  0.275609748 |        ideal
#     3 |    3000 |      10 |  0.140205393 |        ideal
#     4 |    4000 |       5 |  0.206215576 |        ideal
#     5 |    5000 |       8 |  0.094770557 |            f
#     6 |    6000 |      11 |  0.036593552 |        ideal
#     7 |    7000 |       6 |  0.154705654 |        ideal
#     8 |    8000 |       5 |  0.315854410 |        ideal
#     9 |    9000 |       6 |  0.045520792 |        ideal
#    10 |   10000 |      11 |  0.079442002 |        ideal
#    11 |   11000 |      14 |  0.187682020 |        ideal
#    12 |   12000 |      14 |  0.121440565 |        ideal
#    13 |   13000 |      18 |  0.050014555 |            f
#    14 |   14000 |      12 |  0.026557221 |        ideal
#    15 |   15000 |      15 |  0.180222791 |        ideal
#    16 |   16000 |      17 |  0.047523544 |        ideal
# ...

# %%
class MyProblem(Problem):
    def __init__(self):
        self.distMatrixA = euclidE100()[0]
        self.distMatrixB = euclidF100()[0]
        super().__init__(n_var=100,
                         n_obj=2,
                         n_constr=0,
                         xl=np.zeros(100),
                         xu=np.zeros(100)+99,
                         elementwise_evaluation=True)

    def _evaluate(self, x, out, *args, **kwargs):
#         print(x)
        f1 = tsp_objective_function(self.distMatrixA, x)
        f2 = tsp_objective_function(self.distMatrixB, x)
        out["F"] = [f1, f2]


problem = MyProblem()

algorithm = NSGA2(pop_size=1000,
                 sampling=get_sampling("perm_random"),
#                    selection=get_selection("tournament"),
                   mutation=get_mutation("perm_inv", prob=0.3),
                   crossover=get_crossover("perm_erx"))

res = minimize(problem,
               algorithm,
               ("n_gen", 1000),
               verbose=True,
               seed=1)

plot = Scatter()
plot.add(res.F, color="red")
plot.show()
# Out:
# ...
# n_gen |  n_eval |  n_nds  |     eps      |  indicator
# ...
#     1 |    1000 |       6 |            - |            -
#     2 |    2000 |       8 |  0.275609748 |        ideal
#     3 |    3000 |      10 |  0.140205393 |        ideal
#     4 |    4000 |       5 |  0.206215576 |        ideal
#     5 |    5000 |       8 |  0.094770557 |            f
#     6 |    6000 |      11 |  0.036593552 |        ideal
#     7 |    7000 |       6 |  0.154705654 |        ideal
#     8 |    8000 |       5 |  0.315854410 |        ideal
#     9 |    9000 |       6 |  0.045520792 |        ideal
#    10 |   10000 |      11 |  0.079442002 |        ideal
#    11 |   11000 |      14 |  0.187682020 |        ideal
#    12 |   12000 |      14 |  0.121440565 |        ideal
#    13 |   13000 |      18 |  0.050014555 |            f
#    14 |   14000 |      12 |  0.026557221 |        ideal
#    15 |   15000 |      15 |  0.180222791 |        ideal
#    16 |   16000 |      17 |  0.047523544 |        ideal
# ...
